# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from mpl_toolkits.basemap import Basemap
from shapely.geometry import Point, Polygon, MultiPoint, MultiPolygon
from shapely.prepared import prep
import fiona
import networkx as nx
from collections import Counter
from matplotlib.collections import PatchCollection
from descartes import PolygonPatch
import json
from pygeocoder import Geocoder
import datetime
import cPickle as pickle
import os
import seaborn as sns
sns.set_style('darkgrid')
sns.set_palette('husl')

# %%
from matplotlib import rc
rc('font', **{'family':'sans-serif',
    'sans-serif':['Helvetica'],
    'monospace': ['Inconsolata'],
    'serif': ['Adobe Garamamond Pro']})

# %%
data_list = os.listdir('place/')

# %%
dict_list = []
for dat in data_list:
    print dat
    with open('place/'+dat, 'r') as f:
        dict_list.append(pickle.load(f))
# Out:
# 1300 On Fillmore.pkl
# 83 Proof.pkl
# A'Gaci.pkl
# Actual Cafe.pkl
# Alana's Cafe.pkl
# Amelie.pkl
# Angeline's Louisiana Kitchen.pkl
# Anthropologie.pkl
# Aquatic Park.pkl
# Arlequin Cafe & Food-To-Go.pkl
# Au Coquelet.pkl
# Auntie April's Chicken, Waffles, & Soul Food Restaurant.pkl
# Avatar's.pkl
# Avenue.pkl
# Aziza.pkl
# Baby Gap.pkl
# Balboa Cafe.pkl
# Bar Agricole.pkl
# BCBG.pkl
# bebe Bay Street.pkl
# Bedwell Bayfront Park.pkl
# Beehive Clothing.pkl
# Bender's Bar & Grill.pkl
# Benu.pkl
# Bill's Cafe.pkl
# Bix.pkl
# Blue Bottle Coffee.pkl
# Blush! Wine Bar.pkl
# Boulevard.pkl
# Brazil Cafe.pkl
# Brenda's French Soul Food.pkl
# Brown Sugar Kitchen.pkl
# Buena Vista Park.pkl
# Cafe Venetia.pkl
# Cavallo Point Lodge.pkl
# César Chávez Park.pkl
# Chapeau!.pkl
# Charlotte Russe.pkl
# Cheese Board Pizza.pkl
# Chez Panisse.pkl
# Cigar Bar & Grill.pkl
# Commonwealth.pkl
# Corona Heights Park.pkl
# Cotogna.pkl
# Coupa Cafe.pkl
# Coyote Hills Regional Park.pkl
# Crazy 8.pkl
# Creekside Inn.pkl
# Crossroads Cafe.pkl
# Cuesta Park.pkl
# Dottie's True Blue Cafe.pkl
# Eagle Cafe.pkl
# Econo Lodge.pkl
# Epicenter Cafe.pkl
# Express - Hillsdale.pkl
# Famous Food Restaurant.pkl
# Farallon.pkl
# farmerbrown.pkl
# Fast Food Francais.pkl
# Flea Street.pkl
# Flour + Water.pkl
# Free People.pkl
# Gialina.pkl
# Glen Canyon Park.pkl
# Golden Boy Pizza.pkl
# Golden Gate Park.pkl
# Grand View Park.pkl
# Greens Restaurant.pkl
# Grove Yerba Buena.pkl
# Guerilla Cafe.pkl
# Gymboree.pkl
# H&M.pkl
# Half Moon Bay Lodge.pkl
# Hard Knox Cafe and San Francisco Soul Food Restaurant.pkl
# Hog Island Oyster Co.pkl
# Howie's Artisan Pizza.pkl
# Huddart Park.pkl
# IHG Army Hotels Camp Parks.pkl
# Inn at the Presidio.pkl
# Inverness Valley Inn.pkl
# Janie and Jack.pkl
# John McLaren Park.pkl
# Just For You Cafe.pkl
# K&G Fashion Superstore.pkl
# Kasa Indian Eatery.pkl
# Kelly Park.pkl
# Kennedy Park.pkl
# Kiss Seafood.pkl
# L'Ardoise.pkl
# La Costanera.pkl
# La Folie.pkl
# Lafayette Park.pkl
# Lena's Soul Food Cafe.pkl
# Lillie Mae's House of Soul Food.pkl
# Lingonberry Farm.pkl
# Little Star Pizza.pkl
# Lodging Innovations.pkl
# Loft.pkl
# Madras Cafe.pkl
# Manka's Inverness Lodge.pkl
# Marin Lodge.pkl
# Mario's Bohemian Cigar Store Cafe.pkl
# Martuni's.pkl
# Matching Half Cafe.pkl
# Menlo Park Maintenance.pkl
# Mercury Cafe.pkl
# Michael Mina.pkl
# Millennium.pkl
# Mission Beach Cafe.pkl
# Mojo Bicycle Cafe.pkl
# Motel Inverness.pkl
# Mozzeria.pkl
# Napoletana Pizzeria.pkl
# Navy Lodge.pkl
# Nealon Park.pkl
# Nellie's Soulfood Restaurant & Bar.pkl
# Nopa.pkl
# Old Navy.pkl
# Oliveto Restaurant.pkl
# Osprey Peak Bed & Breakfast.pkl
# Papaya Clothing.pkl
# Patxi's Pizza Palo Alto.pkl
# Peña Pachamama.pkl
# Pican Restaurant.pkl
# Pizzaiolo.pkl
# Pizzetta 211.pkl
# Pluto's.pkl
# Point Reyes Schoolhouse Lodging.pkl
# Point Reyes Seashore Lodge.pkl
# Press Club.pkl
# Quince.pkl
# Rainbow Pizza.pkl
# Redwood Regional Park.pkl
# Restaurant Gary Danko.pkl
# Revolution Cafe.pkl
# Rickhouse.pkl
# Saturn Cafe.pkl
# Scend's Restaurant.pkl
# Sears Fine Food.pkl
# Souley Vegan.pkl
# Souls Restaurant.pkl
# South Park Cafe.pkl
# Stable Cafe.pkl
# State Bird Provisions.pkl
# Stephanos Soul Food Restaurant.pkl
# Table Café.pkl
# Terun.pkl
# Thai Cafe Restaurant.pkl
# The Black Heron® Inn.pkl
# The Broken Record.pkl
# The Front Porch.pkl
# The Hidden Vine.pkl
# The Limited.pkl
# The Lodge At Tiburon.pkl
# The Plant Cafe Organic.pkl
# The Sandpiper Lodging at the Beach.pkl
# The Slanted Door.pkl
# The View.pkl
# Tilden Regional Park.pkl
# Tomales Bay Resort & Marina.pkl
# Tommaso's Ristorante Italiano.pkl
# Tony's Pizza Napoletana.pkl
# Torrid.pkl
# Una Pizza Napoletana.pkl
# Universal Cafe.pkl
# Velo Rouge Cafe.pkl
# Vesta.pkl
# Victoria Manalo Draves Park.pkl
# Waterfront Pizza.pkl
# Yield.pkl
# Za Pizza.pkl
# Zero Zero.pkl
# Zuni Café.pkl

# %%
df = pd.DataFrame(dict_list)

# %%
newdf = df[['name','geometry', 'place_id', 'types']]

# %%
newdf['lat'] = newdf['geometry'].apply(lambda x: x['location']['lat'])
newdf['long'] = newdf['geometry'].apply(lambda x: x['location']['lng'])

# %%
newdf.drop('geometry',axis=1,inplace=True)

# %%
newdf
# Out:
#                                                   name  \
# 0                                     1300 On Fillmore
# 1                                             83 Proof
# 2                                               A'Gaci
# 3                                          Actual Cafe
# 4                                         Alana's Cafe
# 5                                               Amelie
# 6                         Angeline's Louisiana Kitchen
# 7                                        Anthropologie
# 8                                         Aquatic Park
# 9                           Arlequin Cafe & Food-To-Go
# 10                                         Au Coquelet
# 11   Auntie April's Chicken, Waffles, & Soul Food R...
# 12                                            Avatar's
# 13                                              Avenue
# 14                                               Aziza
# 15                                            Baby Gap
# 16                                         Balboa Cafe
# 17                                        Bar Agricole
# 18                                                BCBG
# 19                                     bebe Bay Street
# 20                               Bedwell Bayfront Park
# 21                                    Beehive Clothing
# 22                                Bender's Bar & Grill
# 23                                                Benu
# 24                                         Bill's Cafe
# 25                                                 Bix
# 26                                  Blue Bottle Coffee
# 27                                     Blush! Wine Bar
# 28                                           Boulevard
# 29                                         Brazil Cafe
# ..                                                 ...
# 143                              State Bird Provisions
# 144                     Stephanos Soul Food Restaurant
# 145                                         Table Café
# 146                                              Terun
# 147                               Thai Cafe Restaurant
# 148                               The Black Heron® Inn
# 149                                  The Broken Record
# 150                                    The Front Porch
# 151                                    The Hidden Vine
# 152                                        The Limited
# 153                               The Lodge At Tiburon
# 154                             The Plant Cafe Organic
# 155                 The Sandpiper Lodging at the Beach
# 156                                   The Slanted Door
# 157                                           The View
# 158                               Tilden Regional Park
# 159                        Tomales Bay Resort & Marina
# 160                      Tommaso's Ristorante Italiano
# 161                            Tony's Pizza Napoletana
# 162                                             Torrid
# 163                               Una Pizza Napoletana
# 164                                     Universal Cafe
# 165                                    Velo Rouge Cafe
# 166                                              Vesta
# 167                        Victoria Manalo Draves Park
# 168                                   Waterfront Pizza
# 169                                              Yield
# 170                                           Za Pizza
# 171                                          Zero Zero
# 172                                         Zuni Café.
#
#                         place_id  \
# 0    ChIJZbMizLuAhYARKiMObMwPGfc
# 1    ChIJr29cEGOAhYARGODjlpUST5A
# 2    ChIJVSjv47dmhYARFJi3vYC-QTg
# 3    ChIJJWkwLWF-hYARMvBio7rIkmA
# 4    ChIJd2ozDayjj4ARRfACIFI2LuY
# 5    ChIJ88G-quuAhYAR7bj0Yhr8gwI
# 6    ChIJh_wjBJ1-hYARK2XCkZUkbg0
# 7    ChIJt0Qv0tx-hYARkOFQsWTWePw
# 8    ChIJQ09tqOGAhYARinfjX2EOfaM
# 9    ChIJr7uwv5iAhYAR4OZfo28tCME
# 10   ChIJU4rlzp5-hYARhtqduurlWiE
# 11   ChIJSyGZhgV_j4AR8gsKMwaE38c
# 12   ChIJjdERDQWFhYARvpaghgB3HQ4
# 13   ChIJhw93A9hmhYARPsNerJ_46nk
# 14   ChIJb-KW6Q-HhYAR4NlucuMP_HE
# 15   ChIJrcbDd0GHj4AROcWbRC1JjkY
# 16   ChIJYXn3mdCAhYAR97Hkb3wD660
# 17   ChIJCSdjKSZ-j4ARY5HrLSxbatQ
# 18   ChIJMVeA3o6AhYARmEbQ6kLfKtM
# 19   ChIJx1wl3UN-hYARYu9AJY90uUA
# 20   ChIJKd3b4cy8j4ARoYmzezJVPko
# 21   ChIJF4kIsLmHj4ARts2huZUErJ0
# 22   ChIJj1AKlzt-j4ARCHHWunlrEcw
# 23   ChIJSToWqn2AhYAR1CuH2iGMvuo
# 24   ChIJ9VUClAvLj4ARHWChPIsYVZA
# 25   ChIJDZ0ZOPWAhYARkZFd-uCioMs
# 26   ChIJSy28upiAhYARkoxpzFnW7b4
# 27   ChIJpyuHNRt-j4ARi-WLHR3Fsto
# 28   ChIJF-zbSmSAhYARvOafjdCRszQ
# 29   ChIJMcOsP55-hYARHTQro0WwlGY
# ..                           ...
# 143  ChIJQ7kGpLmAhYARKeCe2pDobWk
# 144  ChIJeeTuHFVzhYARoFmbo5JHxfk
# 145  ChIJjwNlLLuQhYARALt0FVHdvaY
# 146  ChIJtXQ38-W6j4AR44dFBS3v120
# 147  ChIJufcwKCXJj4AR2udyrSEul7E
# 148  ChIJza7d2dvFhYARs7mytVrs3KQ
# 149  ChIJEVRUIJp-j4ARb43ptfnaz_w
# 150  ChIJn8Ixw0J-j4ARb073TlyhmZw
# 151  ChIJs7XIGo6AhYAR61UlzRqmdb0
# 152  ChIJQfTev3Tsj4AR6B-IcgRfR8s
# 153  ChIJ8WTz_oeEhYAR1M95VSYTlzs
# 154  ChIJAf9gS2eAhYARpVckgEzu_XM
# 155  ChIJ695bZdKThYARKGtcr2TDVYw
# 156  ChIJWTGPjmaAhYARnYsfhjHT8JM
# 157  ChIJZZ_cOYaAhYARnyfbDrAkvJ8
# 158  ChIJlR5fQ_F7hYARO9bet3eMP3s
# 159  ChIJL9WkTpjPhYARqrPmOrlsSG8
# 160  ChIJD-7c9fSAhYARO7hy4de6RBY
# 161  ChIJHXHcEvGAhYARQPuHNN78s78
# 162  ChIJP5NLubt9j4ARhCgzc0idfvM
# 163  ChIJ_Ziygyd-j4ARtbbdtBPdarg
# 164  ChIJ___I0jB-j4ARgAaAClz2pl8
# 165  ChIJH-SUHkaHhYARMNAz4L9wCks
# 166  ChIJP0gMtKyjj4ARZUDVtINsnm4
# 167  ChIJMb8k6YGAhYARcSOLWWOsvoI
# 168  ChIJ6x0WHCyfj4AREfNcpraaJ4s
# 169  ChIJDw0djbl_j4ARF-oLuBpaXtk
# 170  ChIJZZ4z1uiAhYARd8dViRfgjH8
# 171  ChIJ-VtspYCAhYAR1NlEgy5ye6o
# 172  ChIJO7u9q5-AhYARiSSXyWv9eJ8
#
#                                                  types                lat  \
# 0    [night_club, restaurant, food, bar, point_of_i...         37.7816586
# 1    [bar, restaurant, food, point_of_interest, est...         37.7900567
# 2    [shoe_store, clothing_store, store, point_of_i...  37.96819230000001
# 3    [meal_takeaway, cafe, store, restaurant, food,...          37.846841
# 4    [cafe, restaurant, food, point_of_interest, es...          37.483561
# 5    [liquor_store, store, restaurant, food, bar, p...         37.7930855
# 6    [restaurant, meal_takeaway, food, point_of_int...         37.8682329
# 7    [home_goods_store, clothing_store, store, poin...  37.86887499999999
# 8    [park, amusement_park, point_of_interest, esta...         37.8078379
# 9    [cafe, bar, restaurant, food, point_of_interes...          37.777121
# 10   [cafe, bar, restaurant, food, store, point_of_...  37.87163049999999
# 11   [restaurant, food, point_of_interest, establis...         37.7361328
# 12   [cafe, restaurant, food, point_of_interest, es...         37.8685356
# 13   [clothing_store, store, point_of_interest, est...         37.9748664
# 14   [bar, restaurant, food, point_of_interest, est...         37.7804422
# 15   [clothing_store, store, point_of_interest, est...         37.8104576
# 16   [cafe, bar, restaurant, food, point_of_interes...         37.7988162
# 17   [bar, restaurant, food, point_of_interest, est...  37.77131990000001
# 18   [clothing_store, store, point_of_interest, est...  37.78748820000001
# 19   [clothing_store, store, point_of_interest, est...         37.8354084
# 20            [park, point_of_interest, establishment]  37.49258309999999
# 21   [clothing_store, store, point_of_interest, est...         37.8121035
# 22   [bar, restaurant, food, point_of_interest, est...         37.7601817
# 23   [restaurant, food, point_of_interest, establis...  37.78545200000001
# 24   [cafe, bar, restaurant, food, point_of_interes...         37.3430508
# 25   [night_club, bar, restaurant, food, point_of_i...  37.79687120000001
# 26   [cafe, food, store, point_of_interest, establi...          37.776196
# 27   [restaurant, food, bar, point_of_interest, est...         37.7612941
# 28   [restaurant, food, point_of_interest, establis...           37.79332
# 29   [meal_takeaway, restaurant, food, point_of_int...         37.8724932
# ..                                                 ...                ...
# 143  [restaurant, food, point_of_interest, establis...         37.7837301
# 144  [bar, restaurant, food, point_of_interest, est...          38.122887
# 145  [restaurant, food, point_of_interest, establis...         37.9479772
# 146  [restaurant, food, bar, point_of_interest, est...         37.4259676
# 147  [restaurant, food, point_of_interest, establis...         37.4191397
# 148        [lodging, point_of_interest, establishment]  38.08214110000001
# 149  [bar, restaurant, food, point_of_interest, est...         37.7143118
# 150  [bar, restaurant, food, point_of_interest, est...         37.7438175
# 151      [food, bar, point_of_interest, establishment]         37.7955621
# 152  [clothing_store, jewelry_store, store, point_o...  37.69525170000001
# 153        [lodging, point_of_interest, establishment]         37.8748914
# 154  [bar, restaurant, food, point_of_interest, est...         37.7978158
# 155        [lodging, point_of_interest, establishment]         37.8974867
# 156  [bar, restaurant, food, point_of_interest, est...         37.7961888
# 157  [restaurant, night_club, bar, food, point_of_i...         37.7850079
# 158           [park, point_of_interest, establishment]  37.89276700000001
# 159        [lodging, point_of_interest, establishment]         38.1070379
# 160  [restaurant, food, point_of_interest, establis...         37.7977983
# 161  [restaurant, food, point_of_interest, establis...         37.8003257
# 162  [shoe_store, clothing_store, store, point_of_i...         37.7281631
# 163  [restaurant, food, point_of_interest, establis...         37.7724035
# 164  [cafe, restaurant, food, point_of_interest, es...  37.76061979999999
# 165  [cafe, restaurant, food, store, point_of_inter...         37.7753982
# 166  [restaurant, food, point_of_interest, establis...         37.4867684
# 167           [park, point_of_interest, establishment]         37.7770652
# 168  [restaurant, food, point_of_interest, establis...         37.5441753
# 169      [bar, food, point_of_interest, establishment]  37.75822429999999
# 170  [restaurant, food, point_of_interest, establis...         37.7985452
# 171  [night_club, bar, restaurant, food, point_of_i...         37.7816139
# 172  [restaurant, food, bar, point_of_interest, est...  37.77362420000001
#
#              long
# 0    -122.4319167
# 1    -122.3977007
# 2    -122.0607534
# 3    -122.2847402
# 4     -122.226574
# 5    -122.4210271
# 6    -122.2674992
# 7     -122.299665
# 8     -122.424275
# 9     -122.422774
# 10    -122.270539
# 11   -122.3904508
# 12   -122.5017978
# 13   -122.0392575
# 14   -122.4817328
# 15   -122.2456153
# 16   -122.4361023
# 17   -122.4131368
# 18    -122.408603
# 19   -122.2919952
# 20   -122.1731859
# 21   -122.2007004
# 22   -122.4173055
# 23    -122.399036
# 24   -121.9283595
# 25   -122.4029298
# 26    -122.423316
# 27    -122.435208
# 28    -122.392761
# 29   -122.2667843
# ..            ...
# 143  -122.4329552
# 144  -122.2626963
# 145  -122.5492304
# 146  -122.1454665
# 147  -121.9159796
# 148  -122.8149209
# 149  -122.4369885
# 150  -122.4220131
# 151  -122.4007542
# 152  -121.9252305
# 153  -122.4575448
# 154  -122.3960581
# 155    -122.63844
# 156   -122.394041
# 157  -122.4043332
# 158   -122.242451
# 159  -122.8628638
# 160  -122.4052437
# 161   -122.408985
# 162  -122.4768443
# 163  -122.4154535
# 164  -122.4105624
# 165  -122.4581756
# 166  -122.2267781
# 167  -122.4059946
# 168  -122.2706049
# 169  -122.3886407
# 170  -122.4191528
# 171  -122.4019456
# 172  -122.4216426
#
# [173 rows x 5 columns]

# %%
newdf.to_csv('data/newdf.csv', sep='\t', encoding='utf-8')

# %%
data = pd.read_csv('data/newdf.csv', delimiter='\t')

# %%
data.head()
# Out:
#    Unnamed: 0              name                     place_id  \
# 0           0  1300 On Fillmore  ChIJZbMizLuAhYARKiMObMwPGfc
# 1           1          83 Proof  ChIJr29cEGOAhYARGODjlpUST5A
# 2           2            A'Gaci  ChIJVSjv47dmhYARFJi3vYC-QTg
# 3           3       Actual Cafe  ChIJJWkwLWF-hYARMvBio7rIkmA
# 4           4      Alana's Cafe  ChIJd2ozDayjj4ARRfACIFI2LuY
#
#                                                types        lat        long
# 0  [night_club, restaurant, food, bar, point_of_i...  37.781659 -122.431917
# 1  [bar, restaurant, food, point_of_interest, est...  37.790057 -122.397701
# 2  [shoe_store, clothing_store, store, point_of_i...  37.968192 -122.060753
# 3  [meal_takeaway, cafe, store, restaurant, food,...  37.846841 -122.284740
# 4  [cafe, restaurant, food, point_of_interest, es...  37.483561 -122.226574

# %%
data.columns
# Out:
# Index([u'Unnamed: 0', u'name', u'place_id', u'types', u'lat', u'long'], dtype='object')

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
data.head()
# Out:
#                name                     place_id  \
# 0  1300 On Fillmore  ChIJZbMizLuAhYARKiMObMwPGfc
# 1          83 Proof  ChIJr29cEGOAhYARGODjlpUST5A
# 2            A'Gaci  ChIJVSjv47dmhYARFJi3vYC-QTg
# 3       Actual Cafe  ChIJJWkwLWF-hYARMvBio7rIkmA
# 4      Alana's Cafe  ChIJd2ozDayjj4ARRfACIFI2LuY
#
#                                                types        lat        long
# 0  [night_club, restaurant, food, bar, point_of_i...  37.781659 -122.431917
# 1  [bar, restaurant, food, point_of_interest, est...  37.790057 -122.397701
# 2  [shoe_store, clothing_store, store, point_of_i...  37.968192 -122.060753
# 3  [meal_takeaway, cafe, store, restaurant, food,...  37.846841 -122.284740
# 4  [cafe, restaurant, food, point_of_interest, es...  37.483561 -122.226574

# %%
import pandas as pd
import csv
import itertools
from math import radians, cos, sin, asin, sqrt


def haversine(origin,
              destination):
    """
    Find distance between a pair of lat/lng coordinates
    """
    # convert decimal degrees to radians
    lat1, lon1, lat2, lon2 = map(radians, [float(origin[0]), float(origin[1]),float(destination[0]), float(destination[1])])
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = sin(dlat / 2) ** 2 + cos(lat1) * cos(lat2) * sin(dlon / 2) ** 2
    c = 2 * asin(sqrt(a))
    r = 3959  # Radius of earth in miles
    return '%.2f' % (c * r)

def place_connect(places):
    """
    Cross places and return connection e.g. "v1-2" by ID
    """
    for i in range(len(places)-1):
        for j in range(i+1,len(places)):
            yield 'v'+str(places[i][0])+'-'+str(places[j][0])
            


# Initialize Cleaning
# ##############
# # Duplicates by coordinates (to 5dp)
# data['lat'] = data.lat.round(decimals=5)
# data['long'] = data.long.round(decimals=5)
# data = data.drop_duplicates(['lat', 'long'])

# clean name
data['name'] = data.name.str.upper()
data['name'] = data.name.str.strip()
print(data['name'].value_counts()[:10])

# new dataframe for selected "types"
print(data['types'].value_counts()[:10])
data_cafe = data[data['types'].str.contains("cafe")]
data_restaurants = data[data['types'].str.contains("restaurant")]
data_parks = data[data['types'].str.contains("park")]
data_lodging = data[data['types'].str.contains("lodging")]
data_store = data[data['types'].str.contains("store")]
# Out:
# ACTUAL CAFE              1
# HOWIE'S ARTISAN PIZZA    1
# QUINCE                   1
# BENDER'S BAR & GRILL     1
# SATURN CAFE              1
# CHAPEAU!                 1
# LA COSTANERA             1
# AZIZA                    1
# LITTLE STAR PIZZA        1
# CAVALLO POINT LODGE      1
# Name: name, dtype: int64
# [restaurant, food, point_of_interest, establishment]                     38
# [bar, restaurant, food, point_of_interest, establishment]                23
# [lodging, point_of_interest, establishment]                              19
# [park, point_of_interest, establishment]                                 17
# [clothing_store, store, point_of_interest, establishment]                14
# [cafe, restaurant, food, point_of_interest, establishment]               11
# [cafe, bar, restaurant, food, point_of_interest, establishment]           4
# [night_club, bar, restaurant, food, point_of_interest, establishment]     3
# [meal_takeaway, restaurant, food, point_of_interest, establishment]       3
# [restaurant, food, bar, point_of_interest, establishment]                 3
# Name: types, dtype: int64

# %%
data
# Out:
#                                                   name  \
# 0                                     1300 ON FILLMORE
# 1                                             83 PROOF
# 2                                               A'GACI
# 3                                          ACTUAL CAFE
# 4                                         ALANA'S CAFE
# 5                                               AMELIE
# 6                         ANGELINE'S LOUISIANA KITCHEN
# 7                                        ANTHROPOLOGIE
# 8                                         AQUATIC PARK
# 9                           ARLEQUIN CAFE & FOOD-TO-GO
# 10                                         AU COQUELET
# 11   AUNTIE APRIL'S CHICKEN, WAFFLES, & SOUL FOOD R...
# 12                                            AVATAR'S
# 13                                              AVENUE
# 14                                               AZIZA
# 15                                            BABY GAP
# 16                                         BALBOA CAFE
# 17                                        BAR AGRICOLE
# 18                                                BCBG
# 19                                     BEBE BAY STREET
# 20                               BEDWELL BAYFRONT PARK
# 21                                    BEEHIVE CLOTHING
# 22                                BENDER'S BAR & GRILL
# 23                                                BENU
# 24                                         BILL'S CAFE
# 25                                                 BIX
# 26                                  BLUE BOTTLE COFFEE
# 27                                     BLUSH! WINE BAR
# 28                                           BOULEVARD
# 29                                         BRAZIL CAFE
# ..                                                 ...
# 143                              STATE BIRD PROVISIONS
# 144                     STEPHANOS SOUL FOOD RESTAURANT
# 145                                         TABLE CAFé
# 146                                              TERUN
# 147                               THAI CAFE RESTAURANT
# 148                               THE BLACK HERON® INN
# 149                                  THE BROKEN RECORD
# 150                                    THE FRONT PORCH
# 151                                    THE HIDDEN VINE
# 152                                        THE LIMITED
# 153                               THE LODGE AT TIBURON
# 154                             THE PLANT CAFE ORGANIC
# 155                 THE SANDPIPER LODGING AT THE BEACH
# 156                                   THE SLANTED DOOR
# 157                                           THE VIEW
# 158                               TILDEN REGIONAL PARK
# 159                        TOMALES BAY RESORT & MARINA
# 160                      TOMMASO'S RISTORANTE ITALIANO
# 161                            TONY'S PIZZA NAPOLETANA
# 162                                             TORRID
# 163                               UNA PIZZA NAPOLETANA
# 164                                     UNIVERSAL CAFE
# 165                                    VELO ROUGE CAFE
# 166                                              VESTA
# 167                        VICTORIA MANALO DRAVES PARK
# 168                                   WATERFRONT PIZZA
# 169                                              YIELD
# 170                                           ZA PIZZA
# 171                                          ZERO ZERO
# 172                                         ZUNI CAFé.
#
#                         place_id  \
# 0    ChIJZbMizLuAhYARKiMObMwPGfc
# 1    ChIJr29cEGOAhYARGODjlpUST5A
# 2    ChIJVSjv47dmhYARFJi3vYC-QTg
# 3    ChIJJWkwLWF-hYARMvBio7rIkmA
# 4    ChIJd2ozDayjj4ARRfACIFI2LuY
# 5    ChIJ88G-quuAhYAR7bj0Yhr8gwI
# 6    ChIJh_wjBJ1-hYARK2XCkZUkbg0
# 7    ChIJt0Qv0tx-hYARkOFQsWTWePw
# 8    ChIJQ09tqOGAhYARinfjX2EOfaM
# 9    ChIJr7uwv5iAhYAR4OZfo28tCME
# 10   ChIJU4rlzp5-hYARhtqduurlWiE
# 11   ChIJSyGZhgV_j4AR8gsKMwaE38c
# 12   ChIJjdERDQWFhYARvpaghgB3HQ4
# 13   ChIJhw93A9hmhYARPsNerJ_46nk
# 14   ChIJb-KW6Q-HhYAR4NlucuMP_HE
# 15   ChIJrcbDd0GHj4AROcWbRC1JjkY
# 16   ChIJYXn3mdCAhYAR97Hkb3wD660
# 17   ChIJCSdjKSZ-j4ARY5HrLSxbatQ
# 18   ChIJMVeA3o6AhYARmEbQ6kLfKtM
# 19   ChIJx1wl3UN-hYARYu9AJY90uUA
# 20   ChIJKd3b4cy8j4ARoYmzezJVPko
# 21   ChIJF4kIsLmHj4ARts2huZUErJ0
# 22   ChIJj1AKlzt-j4ARCHHWunlrEcw
# 23   ChIJSToWqn2AhYAR1CuH2iGMvuo
# 24   ChIJ9VUClAvLj4ARHWChPIsYVZA
# 25   ChIJDZ0ZOPWAhYARkZFd-uCioMs
# 26   ChIJSy28upiAhYARkoxpzFnW7b4
# 27   ChIJpyuHNRt-j4ARi-WLHR3Fsto
# 28   ChIJF-zbSmSAhYARvOafjdCRszQ
# 29   ChIJMcOsP55-hYARHTQro0WwlGY
# ..                           ...
# 143  ChIJQ7kGpLmAhYARKeCe2pDobWk
# 144  ChIJeeTuHFVzhYARoFmbo5JHxfk
# 145  ChIJjwNlLLuQhYARALt0FVHdvaY
# 146  ChIJtXQ38-W6j4AR44dFBS3v120
# 147  ChIJufcwKCXJj4AR2udyrSEul7E
# 148  ChIJza7d2dvFhYARs7mytVrs3KQ
# 149  ChIJEVRUIJp-j4ARb43ptfnaz_w
# 150  ChIJn8Ixw0J-j4ARb073TlyhmZw
# 151  ChIJs7XIGo6AhYAR61UlzRqmdb0
# 152  ChIJQfTev3Tsj4AR6B-IcgRfR8s
# 153  ChIJ8WTz_oeEhYAR1M95VSYTlzs
# 154  ChIJAf9gS2eAhYARpVckgEzu_XM
# 155  ChIJ695bZdKThYARKGtcr2TDVYw
# 156  ChIJWTGPjmaAhYARnYsfhjHT8JM
# 157  ChIJZZ_cOYaAhYARnyfbDrAkvJ8
# 158  ChIJlR5fQ_F7hYARO9bet3eMP3s
# 159  ChIJL9WkTpjPhYARqrPmOrlsSG8
# 160  ChIJD-7c9fSAhYARO7hy4de6RBY
# 161  ChIJHXHcEvGAhYARQPuHNN78s78
# 162  ChIJP5NLubt9j4ARhCgzc0idfvM
# 163  ChIJ_Ziygyd-j4ARtbbdtBPdarg
# 164  ChIJ___I0jB-j4ARgAaAClz2pl8
# 165  ChIJH-SUHkaHhYARMNAz4L9wCks
# 166  ChIJP0gMtKyjj4ARZUDVtINsnm4
# 167  ChIJMb8k6YGAhYARcSOLWWOsvoI
# 168  ChIJ6x0WHCyfj4AREfNcpraaJ4s
# 169  ChIJDw0djbl_j4ARF-oLuBpaXtk
# 170  ChIJZZ4z1uiAhYARd8dViRfgjH8
# 171  ChIJ-VtspYCAhYAR1NlEgy5ye6o
# 172  ChIJO7u9q5-AhYARiSSXyWv9eJ8
#
#                                                  types        lat        long
# 0    [night_club, restaurant, food, bar, point_of_i...  37.781659 -122.431917
# 1    [bar, restaurant, food, point_of_interest, est...  37.790057 -122.397701
# 2    [shoe_store, clothing_store, store, point_of_i...  37.968192 -122.060753
# 3    [meal_takeaway, cafe, store, restaurant, food,...  37.846841 -122.284740
# 4    [cafe, restaurant, food, point_of_interest, es...  37.483561 -122.226574
# 5    [liquor_store, store, restaurant, food, bar, p...  37.793085 -122.421027
# 6    [restaurant, meal_takeaway, food, point_of_int...  37.868233 -122.267499
# 7    [home_goods_store, clothing_store, store, poin...  37.868875 -122.299665
# 8    [park, amusement_park, point_of_interest, esta...  37.807838 -122.424275
# 9    [cafe, bar, restaurant, food, point_of_interes...  37.777121 -122.422774
# 10   [cafe, bar, restaurant, food, store, point_of_...  37.871630 -122.270539
# 11   [restaurant, food, point_of_interest, establis...  37.736133 -122.390451
# 12   [cafe, restaurant, food, point_of_interest, es...  37.868536 -122.501798
# 13   [clothing_store, store, point_of_interest, est...  37.974866 -122.039257
# 14   [bar, restaurant, food, point_of_interest, est...  37.780442 -122.481733
# 15   [clothing_store, store, point_of_interest, est...  37.810458 -122.245615
# 16   [cafe, bar, restaurant, food, point_of_interes...  37.798816 -122.436102
# 17   [bar, restaurant, food, point_of_interest, est...  37.771320 -122.413137
# 18   [clothing_store, store, point_of_interest, est...  37.787488 -122.408603
# 19   [clothing_store, store, point_of_interest, est...  37.835408 -122.291995
# 20            [park, point_of_interest, establishment]  37.492583 -122.173186
# 21   [clothing_store, store, point_of_interest, est...  37.812103 -122.200700
# 22   [bar, restaurant, food, point_of_interest, est...  37.760182 -122.417305
# 23   [restaurant, food, point_of_interest, establis...  37.785452 -122.399036
# 24   [cafe, bar, restaurant, food, point_of_interes...  37.343051 -121.928359
# 25   [night_club, bar, restaurant, food, point_of_i...  37.796871 -122.402930
# 26   [cafe, food, store, point_of_interest, establi...  37.776196 -122.423316
# 27   [restaurant, food, bar, point_of_interest, est...  37.761294 -122.435208
# 28   [restaurant, food, point_of_interest, establis...  37.793320 -122.392761
# 29   [meal_takeaway, restaurant, food, point_of_int...  37.872493 -122.266784
# ..                                                 ...        ...         ...
# 143  [restaurant, food, point_of_interest, establis...  37.783730 -122.432955
# 144  [bar, restaurant, food, point_of_interest, est...  38.122887 -122.262696
# 145  [restaurant, food, point_of_interest, establis...  37.947977 -122.549230
# 146  [restaurant, food, bar, point_of_interest, est...  37.425968 -122.145466
# 147  [restaurant, food, point_of_interest, establis...  37.419140 -121.915980
# 148        [lodging, point_of_interest, establishment]  38.082141 -122.814921
# 149  [bar, restaurant, food, point_of_interest, est...  37.714312 -122.436988
# 150  [bar, restaurant, food, point_of_interest, est...  37.743817 -122.422013
# 151      [food, bar, point_of_interest, establishment]  37.795562 -122.400754
# 152  [clothing_store, jewelry_store, store, point_o...  37.695252 -121.925230
# 153        [lodging, point_of_interest, establishment]  37.874891 -122.457545
# 154  [bar, restaurant, food, point_of_interest, est...  37.797816 -122.396058
# 155        [lodging, point_of_interest, establishment]  37.897487 -122.638440
# 156  [bar, restaurant, food, point_of_interest, est...  37.796189 -122.394041
# 157  [restaurant, night_club, bar, food, point_of_i...  37.785008 -122.404333
# 158           [park, point_of_interest, establishment]  37.892767 -122.242451
# 159        [lodging, point_of_interest, establishment]  38.107038 -122.862864
# 160  [restaurant, food, point_of_interest, establis...  37.797798 -122.405244
# 161  [restaurant, food, point_of_interest, establis...  37.800326 -122.408985
# 162  [shoe_store, clothing_store, store, point_of_i...  37.728163 -122.476844
# 163  [restaurant, food, point_of_interest, establis...  37.772403 -122.415453
# 164  [cafe, restaurant, food, point_of_interest, es...  37.760620 -122.410562
# 165  [cafe, restaurant, food, store, point_of_inter...  37.775398 -122.458176
# 166  [restaurant, food, point_of_interest, establis...  37.486768 -122.226778
# 167           [park, point_of_interest, establishment]  37.777065 -122.405995
# 168  [restaurant, food, point_of_interest, establis...  37.544175 -122.270605
# 169      [bar, food, point_of_interest, establishment]  37.758224 -122.388641
# 170  [restaurant, food, point_of_interest, establis...  37.798545 -122.419153
# 171  [night_club, bar, restaurant, food, point_of_i...  37.781614 -122.401946
# 172  [restaurant, food, bar, point_of_interest, est...  37.773624 -122.421643
#
# [173 rows x 5 columns]

# %%
data_cafe
# Out:
#                                                   name  \
# 3                                          ACTUAL CAFE
# 4                                         ALANA'S CAFE
# 9                           ARLEQUIN CAFE & FOOD-TO-GO
# 10                                         AU COQUELET
# 12                                            AVATAR'S
# 16                                         BALBOA CAFE
# 24                                         BILL'S CAFE
# 26                                  BLUE BOTTLE COFFEE
# 33                                        CAFE VENETIA
# 39                                        CHEZ PANISSE
# 44                                          COUPA CAFE
# 48                                     CROSSROADS CAFE
# 50                             DOTTIE'S TRUE BLUE CAFE
# 51                                          EAGLE CAFE
# 53                                      EPICENTER CAFE
# 55                              FAMOUS FOOD RESTAURANT
# 69                                       GUERILLA CAFE
# 73   HARD KNOX CAFE AND SAN FRANCISCO SOUL FOOD RES...
# 82                                   JUST FOR YOU CAFE
# 92                               LENA'S SOUL FOOD CAFE
# 101                  MARIO'S BOHEMIAN CIGAR STORE CAFE
# 103                                 MATCHING HALF CAFE
# 105                                       MERCURY CAFE
# 108                                 MISSION BEACH CAFE
# 109                                  MOJO BICYCLE CAFE
# 118                                 OLIVETO RESTAURANT
# 134                                    REVOLUTION CAFE
# 141                                    SOUTH PARK CAFE
# 142                                        STABLE CAFE
# 164                                     UNIVERSAL CAFE
# 165                                    VELO ROUGE CAFE
#
#                         place_id  \
# 3    ChIJJWkwLWF-hYARMvBio7rIkmA
# 4    ChIJd2ozDayjj4ARRfACIFI2LuY
# 9    ChIJr7uwv5iAhYAR4OZfo28tCME
# 10   ChIJU4rlzp5-hYARhtqduurlWiE
# 12   ChIJjdERDQWFhYARvpaghgB3HQ4
# 16   ChIJYXn3mdCAhYAR97Hkb3wD660
# 24   ChIJ9VUClAvLj4ARHWChPIsYVZA
# 26   ChIJSy28upiAhYARkoxpzFnW7b4
# 33   ChIJkb6X_zi7j4ARKwExaaqqq2A
# 39   ChIJcYtcJaF-hYAR-VzrwZpQY0E
# 44   ChIJY5UIijm7j4ARPkLgY0DXJuI
# 48   ChIJD6D7lXeAhYARpItz2DTPkaU
# 50   ChIJXbxV1JGAhYARPXnXlHU1eoY
# 51   ChIJHSGzi_yAhYARy4aO4ROvmmk
# 53   ChIJnSovWn6AhYARBuVCcKrP2Ts
# 55   ChIJCxug4Ay2j4AROJr_grvgSN4
# 69   ChIJoe7XC6F-hYARYIiq13W7xeM
# 73   ChIJOz17Ibp_j4ARolRA3CEhntA
# 82   ChIJL0eR87l_j4ARzVaL9P2vdDc
# 92   ChIJSVfXqWaGj4ARTqDK1y_D_ls
# 101  ChIJr6IFZPGAhYAR5e3y0GGJp8w
# 103  ChIJraGpLLKAhYARsWqJ-sBBQhM
# 105  ChIJZ_Ak36GAhYARaz2iDa2Cygs
# 108  ChIJbyF-eB9-j4AR5RennmEWsX0
# 109  ChIJzfp706-AhYARn_qk2m_-XmY
# 118  ChIJ_af28sJ9hYARSjYUdP5GYTY
# 134  ChIJsfQS4D5-j4AREe1kqXnitHY
# 141  ChIJU90Z6HiAhYARqIREroX-Sww
# 142  ChIJDS_j2Tp-j4ARx1SqQlnrP4U
# 164  ChIJ___I0jB-j4ARgAaAClz2pl8
# 165  ChIJH-SUHkaHhYARMNAz4L9wCks
#
#                                                  types        lat        long
# 3    [meal_takeaway, cafe, store, restaurant, food,...  37.846841 -122.284740
# 4    [cafe, restaurant, food, point_of_interest, es...  37.483561 -122.226574
# 9    [cafe, bar, restaurant, food, point_of_interes...  37.777121 -122.422774
# 10   [cafe, bar, restaurant, food, store, point_of_...  37.871630 -122.270539
# 12   [cafe, restaurant, food, point_of_interest, es...  37.868536 -122.501798
# 16   [cafe, bar, restaurant, food, point_of_interes...  37.798816 -122.436102
# 24   [cafe, bar, restaurant, food, point_of_interes...  37.343051 -121.928359
# 26   [cafe, food, store, point_of_interest, establi...  37.776196 -122.423316
# 33   [cafe, store, bar, food, point_of_interest, es...  37.447473 -122.160307
# 39   [restaurant, cafe, food, bar, point_of_interes...  37.879590 -122.268964
# 44   [cafe, restaurant, food, store, point_of_inter...  37.444680 -122.161531
# 48   [cafe, food, store, point_of_interest, establi...  37.783155 -122.389043
# 50   [cafe, restaurant, food, point_of_interest, es...  37.781699 -122.410004
# 51   [cafe, restaurant, food, point_of_interest, es...  37.808777 -122.410317
# 53   [cafe, store, restaurant, food, point_of_inter...  37.781491 -122.398975
# 55   [cafe, restaurant, food, point_of_interest, es...  37.366204 -122.016201
# 69   [cafe, store, restaurant, food, point_of_inter...  37.877911 -122.269297
# 73   [restaurant, cafe, food, point_of_interest, es...  37.757529 -122.388509
# 82   [cafe, restaurant, food, point_of_interest, es...  37.758087 -122.388838
# 92   [cafe, restaurant, food, point_of_interest, es...  37.772884 -122.213496
# 101  [cafe, restaurant, food, point_of_interest, es...  37.800271 -122.409879
# 103  [cafe, restaurant, store, food, bar, point_of_...  37.777231 -122.441427
# 105  [cafe, restaurant, food, point_of_interest, es...  37.774003 -122.424374
# 108  [cafe, restaurant, food, point_of_interest, es...  37.768117 -122.424714
# 109  [cafe, bar, food, point_of_interest, establish...  37.775547 -122.438115
# 118  [cafe, restaurant, food, bar, point_of_interes...  37.843862 -122.251856
# 134  [cafe, night_club, bar, restaurant, food, stor...  37.755501 -122.419750
# 141  [cafe, bar, restaurant, food, point_of_interes...  37.781608 -122.394394
# 142  [cafe, meal_takeaway, restaurant, food, store,...  37.763237 -122.415483
# 164  [cafe, restaurant, food, point_of_interest, es...  37.760620 -122.410562
# 165  [cafe, restaurant, food, store, point_of_inter...  37.775398 -122.458176

# %%
data_restaurants
# Out:
#                                                   name  \
# 0                                     1300 ON FILLMORE
# 1                                             83 PROOF
# 3                                          ACTUAL CAFE
# 4                                         ALANA'S CAFE
# 5                                               AMELIE
# 6                         ANGELINE'S LOUISIANA KITCHEN
# 9                           ARLEQUIN CAFE & FOOD-TO-GO
# 10                                         AU COQUELET
# 11   AUNTIE APRIL'S CHICKEN, WAFFLES, & SOUL FOOD R...
# 12                                            AVATAR'S
# 14                                               AZIZA
# 16                                         BALBOA CAFE
# 17                                        BAR AGRICOLE
# 22                                BENDER'S BAR & GRILL
# 23                                                BENU
# 24                                         BILL'S CAFE
# 25                                                 BIX
# 27                                     BLUSH! WINE BAR
# 28                                           BOULEVARD
# 29                                         BRAZIL CAFE
# 30                           BRENDA'S FRENCH SOUL FOOD
# 31                                 BROWN SUGAR KITCHEN
# 36                                            CHAPEAU!
# 38                                  CHEESE BOARD PIZZA
# 39                                        CHEZ PANISSE
# 40                                   CIGAR BAR & GRILL
# 41                                        COMMONWEALTH
# 43                                             COTOGNA
# 44                                          COUPA CAFE
# 50                             DOTTIE'S TRUE BLUE CAFE
# ..                                                 ...
# 131                                      RAINBOW PIZZA
# 133                              RESTAURANT GARY DANKO
# 134                                    REVOLUTION CAFE
# 136                                        SATURN CAFE
# 137                                 SCEND'S RESTAURANT
# 138                                    SEARS FINE FOOD
# 139                                       SOULEY VEGAN
# 140                                   SOULS RESTAURANT
# 141                                    SOUTH PARK CAFE
# 142                                        STABLE CAFE
# 143                              STATE BIRD PROVISIONS
# 144                     STEPHANOS SOUL FOOD RESTAURANT
# 145                                         TABLE CAFé
# 146                                              TERUN
# 147                               THAI CAFE RESTAURANT
# 149                                  THE BROKEN RECORD
# 150                                    THE FRONT PORCH
# 154                             THE PLANT CAFE ORGANIC
# 156                                   THE SLANTED DOOR
# 157                                           THE VIEW
# 160                      TOMMASO'S RISTORANTE ITALIANO
# 161                            TONY'S PIZZA NAPOLETANA
# 163                               UNA PIZZA NAPOLETANA
# 164                                     UNIVERSAL CAFE
# 165                                    VELO ROUGE CAFE
# 166                                              VESTA
# 168                                   WATERFRONT PIZZA
# 170                                           ZA PIZZA
# 171                                          ZERO ZERO
# 172                                         ZUNI CAFé.
#
#                         place_id  \
# 0    ChIJZbMizLuAhYARKiMObMwPGfc
# 1    ChIJr29cEGOAhYARGODjlpUST5A
# 3    ChIJJWkwLWF-hYARMvBio7rIkmA
# 4    ChIJd2ozDayjj4ARRfACIFI2LuY
# 5    ChIJ88G-quuAhYAR7bj0Yhr8gwI
# 6    ChIJh_wjBJ1-hYARK2XCkZUkbg0
# 9    ChIJr7uwv5iAhYAR4OZfo28tCME
# 10   ChIJU4rlzp5-hYARhtqduurlWiE
# 11   ChIJSyGZhgV_j4AR8gsKMwaE38c
# 12   ChIJjdERDQWFhYARvpaghgB3HQ4
# 14   ChIJb-KW6Q-HhYAR4NlucuMP_HE
# 16   ChIJYXn3mdCAhYAR97Hkb3wD660
# 17   ChIJCSdjKSZ-j4ARY5HrLSxbatQ
# 22   ChIJj1AKlzt-j4ARCHHWunlrEcw
# 23   ChIJSToWqn2AhYAR1CuH2iGMvuo
# 24   ChIJ9VUClAvLj4ARHWChPIsYVZA
# 25   ChIJDZ0ZOPWAhYARkZFd-uCioMs
# 27   ChIJpyuHNRt-j4ARi-WLHR3Fsto
# 28   ChIJF-zbSmSAhYARvOafjdCRszQ
# 29   ChIJMcOsP55-hYARHTQro0WwlGY
# 30   ChIJZ9s5SJeAhYARIX3Fxl6oj6c
# 31   ChIJY5-blyJ-hYARrkBrUbAzT94
# 36   ChIJs0HxgDmHhYARAoIYlNJMScA
# 38   ChIJr5hMNKF-hYARxmkk-5t0SzE
# 39   ChIJcYtcJaF-hYAR-VzrwZpQY0E
# 40   ChIJWdokI_WAhYARtk-RF_um-ks
# 41   ChIJoyoBvjx-j4ARNUWlMkjGUL4
# 43   ChIJA0YvGPWAhYAReXmaDTTdWzU
# 44   ChIJY5UIijm7j4ARPkLgY0DXJuI
# 50   ChIJXbxV1JGAhYARPXnXlHU1eoY
# ..                           ...
# 131  ChIJJQ0wDMifj4ARJH4RAlBBVkQ
# 133  ChIJq342JeGAhYARwdtH9tlX7gg
# 134  ChIJsfQS4D5-j4AREe1kqXnitHY
# 136  ChIJ7RuSj51-hYAR92XYj0iOPx4
# 137  ChIJhalipRF-hYARBiJntQ-uIRM
# 138  ChIJlW39lY6AhYAR-kYSJfvNY6A
# 139  ChIJ6Std_beAj4ARWpiH_QbONe8
# 140  ChIJt5_ZSQaGj4ARFoCQj0jMxww
# 141  ChIJU90Z6HiAhYARqIREroX-Sww
# 142  ChIJDS_j2Tp-j4ARx1SqQlnrP4U
# 143  ChIJQ7kGpLmAhYARKeCe2pDobWk
# 144  ChIJeeTuHFVzhYARoFmbo5JHxfk
# 145  ChIJjwNlLLuQhYARALt0FVHdvaY
# 146  ChIJtXQ38-W6j4AR44dFBS3v120
# 147  ChIJufcwKCXJj4AR2udyrSEul7E
# 149  ChIJEVRUIJp-j4ARb43ptfnaz_w
# 150  ChIJn8Ixw0J-j4ARb073TlyhmZw
# 154  ChIJAf9gS2eAhYARpVckgEzu_XM
# 156  ChIJWTGPjmaAhYARnYsfhjHT8JM
# 157  ChIJZZ_cOYaAhYARnyfbDrAkvJ8
# 160  ChIJD-7c9fSAhYARO7hy4de6RBY
# 161  ChIJHXHcEvGAhYARQPuHNN78s78
# 163  ChIJ_Ziygyd-j4ARtbbdtBPdarg
# 164  ChIJ___I0jB-j4ARgAaAClz2pl8
# 165  ChIJH-SUHkaHhYARMNAz4L9wCks
# 166  ChIJP0gMtKyjj4ARZUDVtINsnm4
# 168  ChIJ6x0WHCyfj4AREfNcpraaJ4s
# 170  ChIJZZ4z1uiAhYARd8dViRfgjH8
# 171  ChIJ-VtspYCAhYAR1NlEgy5ye6o
# 172  ChIJO7u9q5-AhYARiSSXyWv9eJ8
#
#                                                  types        lat        long
# 0    [night_club, restaurant, food, bar, point_of_i...  37.781659 -122.431917
# 1    [bar, restaurant, food, point_of_interest, est...  37.790057 -122.397701
# 3    [meal_takeaway, cafe, store, restaurant, food,...  37.846841 -122.284740
# 4    [cafe, restaurant, food, point_of_interest, es...  37.483561 -122.226574
# 5    [liquor_store, store, restaurant, food, bar, p...  37.793085 -122.421027
# 6    [restaurant, meal_takeaway, food, point_of_int...  37.868233 -122.267499
# 9    [cafe, bar, restaurant, food, point_of_interes...  37.777121 -122.422774
# 10   [cafe, bar, restaurant, food, store, point_of_...  37.871630 -122.270539
# 11   [restaurant, food, point_of_interest, establis...  37.736133 -122.390451
# 12   [cafe, restaurant, food, point_of_interest, es...  37.868536 -122.501798
# 14   [bar, restaurant, food, point_of_interest, est...  37.780442 -122.481733
# 16   [cafe, bar, restaurant, food, point_of_interes...  37.798816 -122.436102
# 17   [bar, restaurant, food, point_of_interest, est...  37.771320 -122.413137
# 22   [bar, restaurant, food, point_of_interest, est...  37.760182 -122.417305
# 23   [restaurant, food, point_of_interest, establis...  37.785452 -122.399036
# 24   [cafe, bar, restaurant, food, point_of_interes...  37.343051 -121.928359
# 25   [night_club, bar, restaurant, food, point_of_i...  37.796871 -122.402930
# 27   [restaurant, food, bar, point_of_interest, est...  37.761294 -122.435208
# 28   [restaurant, food, point_of_interest, establis...  37.793320 -122.392761
# 29   [meal_takeaway, restaurant, food, point_of_int...  37.872493 -122.266784
# 30   [restaurant, food, point_of_interest, establis...  37.782915 -122.418946
# 31   [restaurant, food, point_of_interest, establis...  37.820328 -122.288797
# 36   [bar, restaurant, food, point_of_interest, est...  37.783338 -122.460690
# 38   [restaurant, food, point_of_interest, establis...  37.879872 -122.269479
# 39   [restaurant, cafe, food, bar, point_of_interes...  37.879590 -122.268964
# 40   [bar, restaurant, food, point_of_interest, est...  37.797071 -122.403386
# 41   [restaurant, food, point_of_interest, establis...  37.761319 -122.419640
# 43   [restaurant, food, point_of_interest, establis...  37.797445 -122.403575
# 44   [cafe, restaurant, food, store, point_of_inter...  37.444680 -122.161531
# 50   [cafe, restaurant, food, point_of_interest, es...  37.781699 -122.410004
# ..                                                 ...        ...         ...
# 131  [restaurant, food, point_of_interest, establis...  37.521253 -122.337360
# 133  [restaurant, food, point_of_interest, establis...  37.805872 -122.420631
# 134  [cafe, night_club, bar, restaurant, food, stor...  37.755501 -122.419750
# 136  [restaurant, food, point_of_interest, establis...  37.869771 -122.266004
# 137  [restaurant, food, point_of_interest, establis...  37.827700 -122.279062
# 138  [store, bar, restaurant, food, point_of_intere...  37.788813 -122.408698
# 139  [restaurant, food, point_of_interest, establis...  37.797020 -122.276088
# 140  [restaurant, food, point_of_interest, establis...  37.770578 -122.184392
# 141  [cafe, bar, restaurant, food, point_of_interes...  37.781608 -122.394394
# 142  [cafe, meal_takeaway, restaurant, food, store,...  37.763237 -122.415483
# 143  [restaurant, food, point_of_interest, establis...  37.783730 -122.432955
# 144  [bar, restaurant, food, point_of_interest, est...  38.122887 -122.262696
# 145  [restaurant, food, point_of_interest, establis...  37.947977 -122.549230
# 146  [restaurant, food, bar, point_of_interest, est...  37.425968 -122.145466
# 147  [restaurant, food, point_of_interest, establis...  37.419140 -121.915980
# 149  [bar, restaurant, food, point_of_interest, est...  37.714312 -122.436988
# 150  [bar, restaurant, food, point_of_interest, est...  37.743817 -122.422013
# 154  [bar, restaurant, food, point_of_interest, est...  37.797816 -122.396058
# 156  [bar, restaurant, food, point_of_interest, est...  37.796189 -122.394041
# 157  [restaurant, night_club, bar, food, point_of_i...  37.785008 -122.404333
# 160  [restaurant, food, point_of_interest, establis...  37.797798 -122.405244
# 161  [restaurant, food, point_of_interest, establis...  37.800326 -122.408985
# 163  [restaurant, food, point_of_interest, establis...  37.772403 -122.415453
# 164  [cafe, restaurant, food, point_of_interest, es...  37.760620 -122.410562
# 165  [cafe, restaurant, food, store, point_of_inter...  37.775398 -122.458176
# 166  [restaurant, food, point_of_interest, establis...  37.486768 -122.226778
# 168  [restaurant, food, point_of_interest, establis...  37.544175 -122.270605
# 170  [restaurant, food, point_of_interest, establis...  37.798545 -122.419153
# 171  [night_club, bar, restaurant, food, point_of_i...  37.781614 -122.401946
# 172  [restaurant, food, bar, point_of_interest, est...  37.773624 -122.421643
#
# [105 rows x 5 columns]

# %%
data_parks
# Out:
#                             name                     place_id  \
# 8                   AQUATIC PARK  ChIJQ09tqOGAhYARinfjX2EOfaM
# 20         BEDWELL BAYFRONT PARK  ChIJKd3b4cy8j4ARoYmzezJVPko
# 32              BUENA VISTA PARK  ChIJc-fv16uAhYARQNxL3WZRYHw
# 35             CéSAR CHáVEZ PARK  ChIJFTWqXi5_hYARimk-cK6Tl_g
# 42           CORONA HEIGHTS PARK  ChIJX3DWQgJ-j4ARxWqSTDOy_CU
# 45    COYOTE HILLS REGIONAL PARK  ChIJRT7ghwq-j4ARQ68X9Fox0kE
# 49                   CUESTA PARK  ChIJ8QmpntO2j4ARX1iGIbLixxY
# 63              GLEN CANYON PARK  ChIJ9SlCdnZ-j4AR86EzE6c9NY8
# 65              GOLDEN GATE PARK  ChIJY_dFYHKHhYARMKc772iLvnE
# 66               GRAND VIEW PARK  ChIJFS16LmCHhYAR9-5CGavbV2k
# 76                  HUDDART PARK  ChIJbxHK_i-hj4ARsuIi3YGxk7E
# 81             JOHN MCLAREN PARK  ChIJ67-gn-5-j4ARcyjzTqE8ZdU
# 85                    KELLY PARK  ChIJq8lDuLO8j4AR0OQehFz2fzk
# 86                  KENNEDY PARK  ChIJQdC8kQaRj4ARO9iBDnjPSpE
# 91                LAFAYETTE PARK  ChIJC3O0GsGAhYAR4JK4ut4xPsM
# 104       MENLO PARK MAINTENANCE  ChIJLUokOk27j4AReFpr11KdA0w
# 114                  NEALON PARK  ChIJcxADqbakj4ARF55yRHFLJVY
# 132        REDWOOD REGIONAL PARK  ChIJQRWV0WKIj4AREtwLqNxJxs4
# 158         TILDEN REGIONAL PARK  ChIJlR5fQ_F7hYARO9bet3eMP3s
# 167  VICTORIA MANALO DRAVES PARK  ChIJMb8k6YGAhYARcSOLWWOsvoI
#
#                                                  types        lat        long
# 8    [park, amusement_park, point_of_interest, esta...  37.807838 -122.424275
# 20            [park, point_of_interest, establishment]  37.492583 -122.173186
# 32   [park, natural_feature, point_of_interest, est...  37.768203 -122.441770
# 35            [park, point_of_interest, establishment]  37.871621 -122.320412
# 42            [park, point_of_interest, establishment]  37.765312 -122.438585
# 45            [park, point_of_interest, establishment]  37.553283 -122.085435
# 49            [park, point_of_interest, establishment]  37.371931 -122.079563
# 63            [park, point_of_interest, establishment]  37.741559 -122.443185
# 65            [park, point_of_interest, establishment]  37.769421 -122.486214
# 66            [park, point_of_interest, establishment]  37.756263 -122.471845
# 76            [park, point_of_interest, establishment]  37.436012 -122.299238
# 81            [park, point_of_interest, establishment]  37.719309 -122.419374
# 85            [park, point_of_interest, establishment]  37.478596 -122.168046
# 86   [amusement_park, park, point_of_interest, esta...  37.668071 -122.121376
# 91            [park, point_of_interest, establishment]  37.791615 -122.427613
# 104           [park, point_of_interest, establishment]  37.454198 -122.173455
# 114           [park, point_of_interest, establishment]  37.448107 -122.180570
# 132           [park, point_of_interest, establishment]  37.813875 -122.166090
# 158           [park, point_of_interest, establishment]  37.892767 -122.242451
# 167           [park, point_of_interest, establishment]  37.777065 -122.405995

# %%
data_lodging
# Out:
#                                    name                     place_id  \
# 34                  CAVALLO POINT LODGE  ChIJi3J-pCWEhYARxYRB_BqquOA
# 47                        CREEKSIDE INN  ChIJk-81NEQzjoARbseaaQj2g_E
# 52                          ECONO LODGE  ChIJq0-3oE2Sj4ARLTB1NpnLN7Q
# 72                  HALF MOON BAY LODGE  ChIJnfXzUXILj4ARu-Rak_8q0ow
# 77           IHG ARMY HOTELS CAMP PARKS  ChIJSfJgPSDsj4ARVapHam2QY0k
# 78                  INN AT THE PRESIDIO  ChIJ24LodCiHhYAR3sr-G5wBU7k
# 79                 INVERNESS VALLEY INN  ChIJJ1X-fL7PhYAR4qr4Encgco4
# 94                     LINGONBERRY FARM  ChIJkZe7ReTFhYARvpnBCO-CLZI
# 96                  LODGING INNOVATIONS  ChIJz6YKzrTLj4ARbLEfUsRxK-U
# 99              MANKA'S INVERNESS LODGE  ChIJMy6lqJzPhYARExzvWXxEyQA
# 100                         MARIN LODGE  ChIJ8z23CuiZhYARb_QVrS8Ui_E
# 110                     MOTEL INVERNESS  ChIJ5_Z34Y_FhYAR2vhMWkWAiVs
# 113                          NAVY LODGE  ChIJczNmRkO3j4ARSoz3BPBebZw
# 119         OSPREY PEAK BED & BREAKFAST  ChIJ9Uqn95XPhYARM1MqcCcsum8
# 127     POINT REYES SCHOOLHOUSE LODGING  ChIJUZpaGX7GhYARhjoA6Dj5cXM
# 128          POINT REYES SEASHORE LODGE  ChIJZUp-4J8HjoARLgMqQJv936o
# 148                THE BLACK HERON® INN  ChIJza7d2dvFhYARs7mytVrs3KQ
# 153                THE LODGE AT TIBURON  ChIJ8WTz_oeEhYAR1M95VSYTlzs
# 155  THE SANDPIPER LODGING AT THE BEACH  ChIJ695bZdKThYARKGtcr2TDVYw
# 159         TOMALES BAY RESORT & MARINA  ChIJL9WkTpjPhYARqrPmOrlsSG8
#
#                                                  types        lat        long
# 34   [spa, health, lodging, point_of_interest, esta...  37.837661 -122.479377
# 47         [lodging, point_of_interest, establishment]  37.418698 -122.135259
# 52         [lodging, point_of_interest, establishment]  37.696145 -122.051321
# 72         [lodging, point_of_interest, establishment]  37.433209 -122.428202
# 77         [lodging, point_of_interest, establishment]  37.720466 -121.903042
# 78         [lodging, point_of_interest, establishment]  37.797112 -122.457825
# 79         [lodging, point_of_interest, establishment]  38.108784 -122.870788
# 94         [lodging, point_of_interest, establishment]  38.084379 -122.809709
# 96         [lodging, point_of_interest, establishment]  37.357520 -121.946970
# 99         [lodging, point_of_interest, establishment]  38.101528 -122.859238
# 100        [lodging, point_of_interest, establishment]  37.985318 -122.525983
# 110        [lodging, point_of_interest, establishment]  38.087843 -122.841000
# 113        [lodging, point_of_interest, establishment]  37.410566 -122.065553
# 119        [lodging, point_of_interest, establishment]  38.106189 -122.871228
# 127        [lodging, point_of_interest, establishment]  38.071701 -122.803533
# 128        [lodging, point_of_interest, establishment]  38.040828 -122.788428
# 148        [lodging, point_of_interest, establishment]  38.082141 -122.814921
# 153        [lodging, point_of_interest, establishment]  37.874891 -122.457545
# 155        [lodging, point_of_interest, establishment]  37.897487 -122.638440
# 159        [lodging, point_of_interest, establishment]  38.107038 -122.862864

# %%
data_store['types']
# Out:
# 2      [shoe_store, clothing_store, store, point_of_i...
# 3      [meal_takeaway, cafe, store, restaurant, food,...
# 5      [liquor_store, store, restaurant, food, bar, p...
# 7      [home_goods_store, clothing_store, store, poin...
# 10     [cafe, bar, restaurant, food, store, point_of_...
# 13     [clothing_store, store, point_of_interest, est...
# 15     [clothing_store, store, point_of_interest, est...
# 18     [clothing_store, store, point_of_interest, est...
# 19     [clothing_store, store, point_of_interest, est...
# 21     [clothing_store, store, point_of_interest, est...
# 26     [cafe, food, store, point_of_interest, establi...
# 33     [cafe, store, bar, food, point_of_interest, es...
# 37     [shoe_store, clothing_store, jewelry_store, st...
# 44     [cafe, restaurant, food, store, point_of_inter...
# 46     [clothing_store, store, point_of_interest, est...
# 48     [cafe, food, store, point_of_interest, establi...
# 53     [cafe, store, restaurant, food, point_of_inter...
# 54     [clothing_store, store, point_of_interest, est...
# 61     [clothing_store, store, point_of_interest, est...
# 69     [cafe, store, restaurant, food, point_of_inter...
# 70     [clothing_store, store, point_of_interest, est...
# 71     [clothing_store, store, point_of_interest, est...
# 80     [clothing_store, store, point_of_interest, est...
# 83     [clothing_store, store, point_of_interest, est...
# 97     [clothing_store, store, point_of_interest, est...
# 103    [cafe, restaurant, store, food, bar, point_of_...
# 117    [clothing_store, store, point_of_interest, est...
# 120    [shoe_store, clothing_store, store, point_of_i...
# 134    [cafe, night_club, bar, restaurant, food, stor...
# 138    [store, bar, restaurant, food, point_of_intere...
# 142    [cafe, meal_takeaway, restaurant, food, store,...
# 152    [clothing_store, jewelry_store, store, point_o...
# 162    [shoe_store, clothing_store, store, point_of_i...
# 165    [cafe, restaurant, food, store, point_of_inter...
# Name: types, dtype: object

# %%
#grab desired places from user_submitted ranking
########################################################
data['places'] = ''
pd.options.mode.chained_assignment = None  # default='war
 

# pick 1
match = data.name.str.contains('(^TILDEN)(.*)( )(REGIONAL)(.*)( )(PARK)')
print(data['name'][match].value_counts()) # Check what hits we are getting
print("Total: ",sum(match))
data['places'][match] = "TRP"

# pick 2
match = data.name.str.contains('(^TOMALES)(.*)( )(BAY)(.*)( )(RESORT)(.*)( )(&)(.*)( )(MARINA)')
print(data['name'][match].value_counts()) # Check what hits we are getting
print("Total: ",sum(match))
data['places'][match] = "TBRM"

#pick 3
match = data.name.str.contains('(^STABLE)(.*)( )(CAFE)')
print(data['name'][match].value_counts()) # Check what hits we are getting
print("Total: ",sum(match))
data['places'][match] = "SC"


#pick 4
match = data.name.str.contains('(^BROWN)(.*)( )(SUGAR)(.*)( )(KITCHEN)')
print(data['name'][match].value_counts()) # Check what hits we are getting
print("Total: ",sum(match))
data['places'][match] = "BSK"


#pick 5
match = data.name.str.contains('(^BLUE)(.*)( )(BOTTLE)(.*)( )(COFFEE)')
print(data['name'][match].value_counts()) # Check what hits we are getting
print("Total: ",sum(match))
data['places'][match] = "BBC"

#pick 6
match = data.name.str.contains('(^CHEESE)(.*)( )(BOARD)(.*)( )(PIZZA)')
print(data['name'][match].value_counts()) # Check what hits we are getting
print("Total: ",sum(match))
data['places'][match] = "CBP"


#pick 7
match = data.name.str.contains('(^THE)(.*)( )(SLANTED)(.*)( )(DOOR)')
print(data['name'][match].value_counts()) # Check what hits we are getting
print("Total: ",sum(match))
data['places'][match] = "TSD"

 
# remove non-filtered entries and add an index
data_filtered = data[data['places'] != ""]
data_filtered['place_id'] = data_filtered.index
 
print(data_filtered['places'].value_counts())
 
# extract selected places in optimization inputs to a list

all_places_lst = data_filtered[['name','lat', 'long', 'place_id']].values.tolist()
print(len(all_places_lst))
print all_places_lst
# Out:
# TILDEN REGIONAL PARK    1
# Name: name, dtype: int64
# ('Total: ', 1)
# TOMALES BAY RESORT & MARINA    1
# Name: name, dtype: int64
# ('Total: ', 1)
# STABLE CAFE    1
# Name: name, dtype: int64
# ('Total: ', 1)
# BROWN SUGAR KITCHEN    1
# Name: name, dtype: int64
# ('Total: ', 1)
# BLUE BOTTLE COFFEE    1
# Name: name, dtype: int64
# ('Total: ', 1)
# CHEESE BOARD PIZZA    1
# Name: name, dtype: int64
# ('Total: ', 1)
# THE SLANTED DOOR    1
# Name: name, dtype: int64
# ('Total: ', 1)
# BBC     1
# TSD     1
# TRP     1
# SC      1
# BSK     1
# CBP     1
# TBRM    1
# Name: places, dtype: int64
# 7
# [['BLUE BOTTLE COFFEE', 37.776196, -122.42331599999999, 26], ['BROWN SUGAR KITCHEN', 37.820327899999995, -122.28879679999999, 31], ['CHEESE BOARD PIZZA', 37.87987229999999, -122.2694794, 38], ['STABLE CAFE', 37.76323670000001, -122.4154832, 142], ['THE SLANTED DOOR', 37.796188799999996, -122.39404099999999, 156], ['TILDEN REGIONAL PARK', 37.892767000000006, -122.242451, 158], ['TOMALES BAY RESORT & MARINA', 38.107037899999995, -122.8628638, 159]]
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:8: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:14: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:20: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:27: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:34: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:40: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
# /anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:47: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.

# %%
data_filtered
# Out:
#                             name  place_id  \
# 26            BLUE BOTTLE COFFEE        26
# 31           BROWN SUGAR KITCHEN        31
# 38            CHEESE BOARD PIZZA        38
# 142                  STABLE CAFE       142
# 156             THE SLANTED DOOR       156
# 158         TILDEN REGIONAL PARK       158
# 159  TOMALES BAY RESORT & MARINA       159
#
#                                                  types        lat        long  \
# 26   [cafe, food, store, point_of_interest, establi...  37.776196 -122.423316
# 31   [restaurant, food, point_of_interest, establis...  37.820328 -122.288797
# 38   [restaurant, food, point_of_interest, establis...  37.879872 -122.269479
# 142  [cafe, meal_takeaway, restaurant, food, store,...  37.763237 -122.415483
# 156  [bar, restaurant, food, point_of_interest, est...  37.796189 -122.394041
# 158           [park, point_of_interest, establishment]  37.892767 -122.242451
# 159        [lodging, point_of_interest, establishment]  38.107038 -122.862864
#
#     places
# 26     BBC
# 31     BSK
# 38     CBP
# 142     SC
# 156    TSD
# 158    TRP
# 159   TBRM

# %%
mission = [37.7599, -122.4148]
berkeley = [37.8716, -122.2727]

cut_off = 20
# Alo concatenate the ID with the name
place_list = [[str(x[3])+"_"+x[0],x[1],x[2]] for x in all_places_lst if
                  float(haversine(berkeley,[x[1],x[2]] )) <= cut_off]
 
print("Cut list contains %d places" % len(place_list)) 
print place_list
# Out:
# Cut list contains 6 places
# [['26_BLUE BOTTLE COFFEE', 37.776196, -122.42331599999999], ['31_BROWN SUGAR KITCHEN', 37.820327899999995, -122.28879679999999], ['38_CHEESE BOARD PIZZA', 37.87987229999999, -122.2694794], ['142_STABLE CAFE', 37.76323670000001, -122.4154832], ['156_THE SLANTED DOOR', 37.796188799999996, -122.39404099999999], ['158_TILDEN REGIONAL PARK', 37.892767000000006, -122.242451]]

# %%
cross_places = [[place_list[i],place_list[j]] 
                for i in range(len(place_list)) 
                for j in range(len(place_list)) 
                if i!=j] 
print(len(cross_places))
print cross_places


# export distances to calculate to a CSV
#########################################
f = open('walk_to_calculate.csv', 'w')
w = csv.writer(f)
w.writerow(["place_A", "Lat_A", "Lon_A", "place_B", "Lat_B","Lon_B"])
for x in cross_places:
    w.writerow([x[0][0],x[0][1],x[0][2],x[1][0],x[1][1],x[1][2]])
f.close()
# Out:
# 30
# [[['26_BLUE BOTTLE COFFEE', 37.776196, -122.42331599999999], ['31_BROWN SUGAR KITCHEN', 37.820327899999995, -122.28879679999999]], [['26_BLUE BOTTLE COFFEE', 37.776196, -122.42331599999999], ['38_CHEESE BOARD PIZZA', 37.87987229999999, -122.2694794]], [['26_BLUE BOTTLE COFFEE', 37.776196, -122.42331599999999], ['142_STABLE CAFE', 37.76323670000001, -122.4154832]], [['26_BLUE BOTTLE COFFEE', 37.776196, -122.42331599999999], ['156_THE SLANTED DOOR', 37.796188799999996, -122.39404099999999]], [['26_BLUE BOTTLE COFFEE', 37.776196, -122.42331599999999], ['158_TILDEN REGIONAL PARK', 37.892767000000006, -122.242451]], [['31_BROWN SUGAR KITCHEN', 37.820327899999995, -122.28879679999999], ['26_BLUE BOTTLE COFFEE', 37.776196, -122.42331599999999]], [['31_BROWN SUGAR KITCHEN', 37.820327899999995, -122.28879679999999], ['38_CHEESE BOARD PIZZA', 37.87987229999999, -122.2694794]], [['31_BROWN SUGAR KITCHEN', 37.820327899999995, -122.28879679999999], ['142_STABLE CAFE', 37.76323670000001, -122.4154832]], [['31_BROWN SUGAR KITCHEN', 37.820327899999995, -122.28879679999999], ['156_THE SLANTED DOOR', 37.796188799999996, -122.39404099999999]], [['31_BROWN SUGAR KITCHEN', 37.820327899999995, -122.28879679999999], ['158_TILDEN REGIONAL PARK', 37.892767000000006, -122.242451]], [['38_CHEESE BOARD PIZZA', 37.87987229999999, -122.2694794], ['26_BLUE BOTTLE COFFEE', 37.776196, -122.42331599999999]], [['38_CHEESE BOARD PIZZA', 37.87987229999999, -122.2694794], ['31_BROWN SUGAR KITCHEN', 37.820327899999995, -122.28879679999999]], [['38_CHEESE BOARD PIZZA', 37.87987229999999, -122.2694794], ['142_STABLE CAFE', 37.76323670000001, -122.4154832]], [['38_CHEESE BOARD PIZZA', 37.87987229999999, -122.2694794], ['156_THE SLANTED DOOR', 37.796188799999996, -122.39404099999999]], [['38_CHEESE BOARD PIZZA', 37.87987229999999, -122.2694794], ['158_TILDEN REGIONAL PARK', 37.892767000000006, -122.242451]], [['142_STABLE CAFE', 37.76323670000001, -122.4154832], ['26_BLUE BOTTLE COFFEE', 37.776196, -122.42331599999999]], [['142_STABLE CAFE', 37.76323670000001, -122.4154832], ['31_BROWN SUGAR KITCHEN', 37.820327899999995, -122.28879679999999]], [['142_STABLE CAFE', 37.76323670000001, -122.4154832], ['38_CHEESE BOARD PIZZA', 37.87987229999999, -122.2694794]], [['142_STABLE CAFE', 37.76323670000001, -122.4154832], ['156_THE SLANTED DOOR', 37.796188799999996, -122.39404099999999]], [['142_STABLE CAFE', 37.76323670000001, -122.4154832], ['158_TILDEN REGIONAL PARK', 37.892767000000006, -122.242451]], [['156_THE SLANTED DOOR', 37.796188799999996, -122.39404099999999], ['26_BLUE BOTTLE COFFEE', 37.776196, -122.42331599999999]], [['156_THE SLANTED DOOR', 37.796188799999996, -122.39404099999999], ['31_BROWN SUGAR KITCHEN', 37.820327899999995, -122.28879679999999]], [['156_THE SLANTED DOOR', 37.796188799999996, -122.39404099999999], ['38_CHEESE BOARD PIZZA', 37.87987229999999, -122.2694794]], [['156_THE SLANTED DOOR', 37.796188799999996, -122.39404099999999], ['142_STABLE CAFE', 37.76323670000001, -122.4154832]], [['156_THE SLANTED DOOR', 37.796188799999996, -122.39404099999999], ['158_TILDEN REGIONAL PARK', 37.892767000000006, -122.242451]], [['158_TILDEN REGIONAL PARK', 37.892767000000006, -122.242451], ['26_BLUE BOTTLE COFFEE', 37.776196, -122.42331599999999]], [['158_TILDEN REGIONAL PARK', 37.892767000000006, -122.242451], ['31_BROWN SUGAR KITCHEN', 37.820327899999995, -122.28879679999999]], [['158_TILDEN REGIONAL PARK', 37.892767000000006, -122.242451], ['38_CHEESE BOARD PIZZA', 37.87987229999999, -122.2694794]], [['158_TILDEN REGIONAL PARK', 37.892767000000006, -122.242451], ['142_STABLE CAFE', 37.76323670000001, -122.4154832]], [['158_TILDEN REGIONAL PARK', 37.892767000000006, -122.242451], ['156_THE SLANTED DOOR', 37.796188799999996, -122.39404099999999]]]

# %%
"""
Helper function to plot map
"""
def geo_network(all_places, places_in_group, connections, name='network_map.html', minutes=120):
    """
    Helper function:
    Plot the network on an easy-to-read google-map
    """
    map = []
    for x in all_places:
        if x[0] in places_in_group:
            # places in cliques
            map.append("<marker name = \"%s\" lat = \"%.5f\" lng = \"%.5f\" col = \"red\"/>"
                       % (x[0],x[1],x[2]))
        else:
            # places not in cliques
            map.append("<marker name = \"%s\" lat = \"%.5f\" lng = \"%.5f\" col = \"green\"/>"
                       % (x[0],x[1],x[2]))
    for x in connections:
        if float(x[-1]) <= minutes:
            # Connections
            map.append("<line latfrom = \"%.5f\" longfrom = \"%.5f\" latto = \"%.5f\" longto = \"%.5f\"/>"
                       % (float(x[1]),float(x[2]),float(x[4]),float(x[5]))) 
    # Map part 1
    htmltext = """<!DOCTYPE html >
 
<style type="text/css">
                        html, body {
                            height: 100%;
                            width: 100%;
                            padding: 0;
                            margin: 0;
                        }
                        .labels {
                            color: black;
                            background-color: white;
                            font-family: "Lucida Grande", "Arial", sans-serif;
                    font-size: 10px;
                            text-align: center;
                    width: 45px;
                            border: 0 solid black;
                            white-space: nowrap;
                        }
                    </style>
 
                    <html>
                    <head>
                    <meta name="viewport" content="initial-scale=1.0, user-scalable=yes" />
                    <meta http-equiv="content-type" content="text/html; charset=UTF-8"/>
                    <title>Network</title>
                    <xml id="myxml">"""
    # Map part 2
    for x in map:
        htmltext += x + "\n"
     
    # Map part 3
    htmltext += """
            </xml>
            <script type="text/javascript" src="https://maps.googleapis.com/maps/api/js?&libraries=geometry"></script>
            <script type="text/javascript" src="http://google-maps-utility-library-v3.googlecode.com/svn/trunk/markerwithlabel/src/markerwithlabel.js"></script>
            <script>
            var XML = document.getElementById("myxml");
            if(XML.documentElement == null)
            XML.documentElement = XML.firstChild;
            var MARKERS = XML.getElementsByTagName("marker");
            var LINES = XML.getElementsByTagName("line");
            function initialize() {
                 var mapOptions = {
                                center: new google.maps.LatLng(37.76324,-122.41548),
                                zoom: 12,
                                styles:
                                [
                                {"featureType":"administrative","stylers":[{ "saturation":-80},{"visibility":"off"}]},
                                {"featureType":"landscape.natural","elementType":"geometry","stylers":[{"color":"#d0e3b4"}]},
                                {"featureType":"landscape.natural.terrain","elementType":"geometry","stylers":[{"visibility":"off"}]},
                                {"featureType":"poi","elementType":"labels","stylers":[{"visibility":"on"}]},
                                {"featureType":"poi.business","elementType":"all","stylers":[{"visibility":"off"}]},
                                {"featureType":"poi.medical","elementType":"geometry","stylers":[{"color":"#fbd3da"}]},
                                {"featureType":"poi.park","elementType":"geometry","stylers":[{"color":"#bde6ab"}]},
                                {"featureType":"road","elementType":"geometry.stroke","stylers":[{"visibility":"off"}]},
                                {"featureType":"road","elementType":"labels","stylers":[{"visibility":"off"}]},
                                {"featureType":"road.highway","elementType":"geometry.fill","stylers":[{"color":"#ffe15f"}]},
                                {"featureType":"road.highway","elementType":"geometry.stroke","stylers":[{"color":"#efd151"}]},
                                {"featureType":"road.arterial","elementType":"geometry.fill","stylers":[{"color":"#ffffff"}]},
                                {"featureType":"road.local","elementType":"geometry.fill","stylers":[{"color":"black"}]},
                                {"featureType":"transit","stylers":[{"visibility":"off"}]},
                                {"featureType":"water","elementType":"geometry","stylers":[{"color":"#a2daf2"}]}
                                ]
                        };
                var map = new google.maps.Map(document.getElementById('map'),
                    mapOptions);
                var bounds = new google.maps.LatLngBounds();
                for (var i = 0; i < MARKERS.length; i++) {
                    var name = MARKERS[i].getAttribute("name");
                    var point_i = new google.maps.LatLng(
                        parseFloat(MARKERS[i].getAttribute("lat")),
                        parseFloat(MARKERS[i].getAttribute("lng")));
                    var col =  MARKERS[i].getAttribute("col")
                    if (col == "green") {
                        var ic = "https://storage.googleapis.com/support-kms-prod/SNP_2752129_en_v0"
                    } else {
                        var ic = "https://storage.googleapis.com/support-kms-prod/SNP_2752125_en_v0"
                    }
                    var marker = new MarkerWithLabel({
                        position: point_i,
                        map: map,
                        icon: ic,
                        //labelContent: name,
                        labelAnchor: new google.maps.Point(22, 0),
                        labelClass: "labels", // the CSS class for the label
                        labelStyle: {opacity: 0.75},
                    })
                    bounds.extend(point_i);
                };          
            for (var i = 0; i < LINES.length; i++) {
                var point_a = new google.maps.LatLng(
                        parseFloat(LINES[i].getAttribute("latfrom")),
                        parseFloat(LINES[i].getAttribute("longfrom")));
                var point_b = new google.maps.LatLng(
                        parseFloat(LINES[i].getAttribute("latto")),
                        parseFloat(LINES[i].getAttribute("longto")));
                var flightPlanCoordinates = [
                    point_a,
                    point_b
                ];
                var flightPath = new google.maps.Polyline({
                    path: flightPlanCoordinates,
                    geodesic: true,
                    strokeColor: 'black',
                    strokeOpacity: 1,
                    strokeWeight: 1
                });
                flightPath.setMap(map);
            };
            }
            google.maps.event.addDomListener(window, 'load', initialize);
            </script>
            </head>
            <body>
            <center>
 
<div id="map" style="width:95%; height:1200px;"></div>
 
            <center>
            </body>
            </html>       
    """
    with open(name, 'w') as f:
        f.write(htmltext)
    f.close()

# %%
import csv
import networkx as nx  
from pylab import *
 
def is_problematic(grp):
    if len(grp) > 2:
        return True
    return False
 
def extract_clusters(clusters):  
    """
    From a list of clusters/groups, extract unique places
    and the cluster if it is problematic
    """
    lst_clqs = []  # Contains all the groups
    unq_places_clq = [] # Contains places in a clique
    for c in clusters:
        if is_problematic(c):
            lst_clqs.append(c)
            for x in c:
                if x not in unq_places_clq:
                    unq_places_clq.append(x)
    return [lst_clqs,unq_places_clq]
 
minutes = 240  
 
# Read in calculated distances
#[store_a],[lat_a],[lon_a],[store_b],[lat_b],[lon_b],[time_min]
in_data = []
with open('walk_to_calculate.csv') as f:
    reader = csv.reader(f)
    headers = next(f)
    for x in reader:
        in_data.append(x)
f.close()

# %%
data_edges = [(x[0],x[3], {'weight': float(haversine([x[4], x[5]], [x[1],x[2]]))}) for x in in_data if float(x[-1]) <= minutes]

# %%
# data_edges = [(x[0],x[3], {'weight': float(haversine([x[4], x[5]], [x[1],x[2]]))}) for x in in_data if float(x[-1]) <= minutes]
# # Add edges


G=nx.Graph()
G.add_edges_from(data_edges)
 
# Clique Analysis
find_cliq = nx.find_cliques(G)
lst_clqs,unq_places_clq = extract_clusters(find_cliq)
                 
print("%d total places in analysis" % len(place_list))
print("%d places in problematic cliques:" % len(unq_places_clq))  
 
print("Problematic cliques:")
for x in lst_clqs:
    print(x)
     
print("Alternatively, problematic clusters:")
for x in nx.connected_components(G):
    print(x)
     

geo_network(place_list, unq_places_clq, in_data, 'unop_network_map.html', minutes) 
 
print("%.0f percent of places in a problematic clique" % (len(unq_places_clq)/len(place_list)*100))
# Out:
# 6 total places in analysis
# 6 places in problematic cliques:
# Problematic cliques:
# ['26_BLUE BOTTLE COFFEE', '38_CHEESE BOARD PIZZA', '158_TILDEN REGIONAL PARK', '31_BROWN SUGAR KITCHEN', '142_STABLE CAFE', '156_THE SLANTED DOOR']
# Alternatively, problematic clusters:
# set(['26_BLUE BOTTLE COFFEE', '31_BROWN SUGAR KITCHEN', '142_STABLE CAFE', '38_CHEESE BOARD PIZZA', '156_THE SLANTED DOOR', '158_TILDEN REGIONAL PARK'])
# 100 percent of places in a problematic clique

# %%
# from pulp import *
 

# prob = LpProblem("Maximise points kept",LpMaximize)
 

# x = []
# for place in unq_places_clq:
#     x.append(LpVariable(place,0,1,LpInteger)) 


# prob += pulp.lpSum(x[i] for i in range(len(unq_places_clq)))
# for one_clique in lst_clqs:   
#     prob += pulp.lpSum(
#         x[unq_places_clq.index(one_clique[i])] 
#         for i in range(len(one_clique))) <= 5

# prob.writeLP("cliques.lp")
# # Solve
# prob.solve()
# # The status of the solution is printed to the screen
# print("Status:", LpStatus[prob.status])
# # Optimum variable values
# drop_points = []
# for v in prob.variables():
#     print(v.name, "=", v.varValue)
#     if v.varValue == 0:
#          drop_points.append(v.name)
            
# print prob.objective
            

# print("Number of points kept = ", int(value(prob.objective)))   
# # Dropping
# print("Number of points dropped = ", len(unq_places_clq) - int(value(prob.objective)))
# print drop_points

# %%
# """
# Test out our new number of cliques
# """
# opt_edges = [x for x in data_edges if (x[0] not in drop_points and x[1] not in drop_points)]
# opt_in_data = [x for x in in_data if (x[0] not in drop_points and x[3] not in drop_points)]
# opt_place_list = [x for x in place_list if x[0] not in drop_points]
# print opt_place_list
# print (opt_edges)


# # Add edges
# opt_G=nx.Graph()
# opt_G.add_edges_from(opt_edges)
# pos = nx.spring_layout(opt_G)
# nx.draw(opt_G,pos,node_color='b', with_labels=True)
# # Clique Analysis
# opt_find_cliq = nx.find_cliques(opt_G)
# opt_lst_clqs,opt_unq_places_clq = extract_clusters(find_cliq)

# print("located %d places in a problematic clique" % len(opt_unq_places_clq))

# # Geographic Diagram (instead)
# geo_network(opt_place_list, opt_unq_places_clq, opt_in_data, 'opt_network_map.html', minutes)

# %%
data_edges
# Out:
# [('26_BLUE BOTTLE COFFEE', '31_BROWN SUGAR KITCHEN', {'weight': 7.95}),
#  ('26_BLUE BOTTLE COFFEE', '38_CHEESE BOARD PIZZA', {'weight': 11.04}),
#  ('26_BLUE BOTTLE COFFEE', '142_STABLE CAFE', {'weight': 0.99}),
#  ('26_BLUE BOTTLE COFFEE', '156_THE SLANTED DOOR', {'weight': 2.11}),
#  ('26_BLUE BOTTLE COFFEE', '158_TILDEN REGIONAL PARK', {'weight': 12.74}),
#  ('31_BROWN SUGAR KITCHEN', '26_BLUE BOTTLE COFFEE', {'weight': 7.95}),
#  ('31_BROWN SUGAR KITCHEN', '38_CHEESE BOARD PIZZA', {'weight': 4.25}),
#  ('31_BROWN SUGAR KITCHEN', '142_STABLE CAFE', {'weight': 7.96}),
#  ('31_BROWN SUGAR KITCHEN', '156_THE SLANTED DOOR', {'weight': 5.98}),
#  ('31_BROWN SUGAR KITCHEN', '158_TILDEN REGIONAL PARK', {'weight': 5.61}),
#  ('38_CHEESE BOARD PIZZA', '26_BLUE BOTTLE COFFEE', {'weight': 11.04}),
#  ('38_CHEESE BOARD PIZZA', '31_BROWN SUGAR KITCHEN', {'weight': 4.25}),
#  ('38_CHEESE BOARD PIZZA', '142_STABLE CAFE', {'weight': 11.33}),
#  ('38_CHEESE BOARD PIZZA', '156_THE SLANTED DOOR', {'weight': 8.92}),
#  ('38_CHEESE BOARD PIZZA', '158_TILDEN REGIONAL PARK', {'weight': 1.72}),
#  ('142_STABLE CAFE', '26_BLUE BOTTLE COFFEE', {'weight': 0.99}),
#  ('142_STABLE CAFE', '31_BROWN SUGAR KITCHEN', {'weight': 7.96}),
#  ('142_STABLE CAFE', '38_CHEESE BOARD PIZZA', {'weight': 11.33}),
#  ('142_STABLE CAFE', '156_THE SLANTED DOOR', {'weight': 2.56}),
#  ('142_STABLE CAFE', '158_TILDEN REGIONAL PARK', {'weight': 13.01}),
#  ('156_THE SLANTED DOOR', '26_BLUE BOTTLE COFFEE', {'weight': 2.11}),
#  ('156_THE SLANTED DOOR', '31_BROWN SUGAR KITCHEN', {'weight': 5.98}),
#  ('156_THE SLANTED DOOR', '38_CHEESE BOARD PIZZA', {'weight': 8.92}),
#  ('156_THE SLANTED DOOR', '142_STABLE CAFE', {'weight': 2.56}),
#  ('156_THE SLANTED DOOR', '158_TILDEN REGIONAL PARK', {'weight': 10.63}),
#  ('158_TILDEN REGIONAL PARK', '26_BLUE BOTTLE COFFEE', {'weight': 12.74}),
#  ('158_TILDEN REGIONAL PARK', '31_BROWN SUGAR KITCHEN', {'weight': 5.61}),
#  ('158_TILDEN REGIONAL PARK', '38_CHEESE BOARD PIZZA', {'weight': 1.72}),
#  ('158_TILDEN REGIONAL PARK', '142_STABLE CAFE', {'weight': 13.01}),
#  ('158_TILDEN REGIONAL PARK', '156_THE SLANTED DOOR', {'weight': 10.63})]

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

G=nx.Graph()
G.add_edges_from(data_edges)
print data_edges
pos = nx.spring_layout(G)
path = nx.shortest_path(G)
plt.figure(figsize=(15,10))
nx.draw_networkx_nodes(G,pos,node_color='b', font_size=7, with_labels=True, font_family='sans-serif')
nx.draw_networkx_edges(G,pos,node_color='c', font_size=7, with_labels=True, font_family='sans-serif')
nx.draw_networkx_edge_labels(G,pos,node_color='c', font_size=7, with_labels=True, font_family='sans-serif')
#nx.draw_networkx_labels(G,pos,node_color='c', font_size=7, with_labels=True, font_family='sans-serif')
# Out:
# [('26_BLUE BOTTLE COFFEE', '31_BROWN SUGAR KITCHEN', {'weight': 7.95}), ('26_BLUE BOTTLE COFFEE', '38_CHEESE BOARD PIZZA', {'weight': 11.04}), ('26_BLUE BOTTLE COFFEE', '142_STABLE CAFE', {'weight': 0.99}), ('26_BLUE BOTTLE COFFEE', '156_THE SLANTED DOOR', {'weight': 2.11}), ('26_BLUE BOTTLE COFFEE', '158_TILDEN REGIONAL PARK', {'weight': 12.74}), ('31_BROWN SUGAR KITCHEN', '26_BLUE BOTTLE COFFEE', {'weight': 7.95}), ('31_BROWN SUGAR KITCHEN', '38_CHEESE BOARD PIZZA', {'weight': 4.25}), ('31_BROWN SUGAR KITCHEN', '142_STABLE CAFE', {'weight': 7.96}), ('31_BROWN SUGAR KITCHEN', '156_THE SLANTED DOOR', {'weight': 5.98}), ('31_BROWN SUGAR KITCHEN', '158_TILDEN REGIONAL PARK', {'weight': 5.61}), ('38_CHEESE BOARD PIZZA', '26_BLUE BOTTLE COFFEE', {'weight': 11.04}), ('38_CHEESE BOARD PIZZA', '31_BROWN SUGAR KITCHEN', {'weight': 4.25}), ('38_CHEESE BOARD PIZZA', '142_STABLE CAFE', {'weight': 11.33}), ('38_CHEESE BOARD PIZZA', '156_THE SLANTED DOOR', {'weight': 8.92}), ('38_CHEESE BOARD PIZZA', '158_TILDEN REGIONAL PARK', {'weight': 1.72}), ('142_STABLE CAFE', '26_BLUE BOTTLE COFFEE', {'weight': 0.99}), ('142_STABLE CAFE', '31_BROWN SUGAR KITCHEN', {'weight': 7.96}), ('142_STABLE CAFE', '38_CHEESE BOARD PIZZA', {'weight': 11.33}), ('142_STABLE CAFE', '156_THE SLANTED DOOR', {'weight': 2.56}), ('142_STABLE CAFE', '158_TILDEN REGIONAL PARK', {'weight': 13.01}), ('156_THE SLANTED DOOR', '26_BLUE BOTTLE COFFEE', {'weight': 2.11}), ('156_THE SLANTED DOOR', '31_BROWN SUGAR KITCHEN', {'weight': 5.98}), ('156_THE SLANTED DOOR', '38_CHEESE BOARD PIZZA', {'weight': 8.92}), ('156_THE SLANTED DOOR', '142_STABLE CAFE', {'weight': 2.56}), ('156_THE SLANTED DOOR', '158_TILDEN REGIONAL PARK', {'weight': 10.63}), ('158_TILDEN REGIONAL PARK', '26_BLUE BOTTLE COFFEE', {'weight': 12.74}), ('158_TILDEN REGIONAL PARK', '31_BROWN SUGAR KITCHEN', {'weight': 5.61}), ('158_TILDEN REGIONAL PARK', '38_CHEESE BOARD PIZZA', {'weight': 1.72}), ('158_TILDEN REGIONAL PARK', '142_STABLE CAFE', {'weight': 13.01}), ('158_TILDEN REGIONAL PARK', '156_THE SLANTED DOOR', {'weight': 10.63})]
# {('142_STABLE CAFE',
#   '156_THE SLANTED DOOR'): <matplotlib.text.Text at 0x125d2da90>,
#  ('142_STABLE CAFE',
#   '158_TILDEN REGIONAL PARK'): <matplotlib.text.Text at 0x125d16390>,
#  ('142_STABLE CAFE',
#   '38_CHEESE BOARD PIZZA'): <matplotlib.text.Text at 0x125d45d90>,
#  ('156_THE SLANTED DOOR',
#   '158_TILDEN REGIONAL PARK'): <matplotlib.text.Text at 0x125d52f10>,
#  ('26_BLUE BOTTLE COFFEE',
#   '142_STABLE CAFE'): <matplotlib.text.Text at 0x125d2d4d0>,
#  ('26_BLUE BOTTLE COFFEE',
#   '156_THE SLANTED DOOR'): <matplotlib.text.Text at 0x125d45210>,
#  ('26_BLUE BOTTLE COFFEE',
#   '158_TILDEN REGIONAL PARK'): <matplotlib.text.Text at 0x125d39c10>,
#  ('26_BLUE BOTTLE COFFEE',
#   '31_BROWN SUGAR KITCHEN'): <matplotlib.text.Text at 0x125d52950>,
#  ('26_BLUE BOTTLE COFFEE',
#   '38_CHEESE BOARD PIZZA'): <matplotlib.text.Text at 0x125d21ed0>,
#  ('31_BROWN SUGAR KITCHEN',
#   '142_STABLE CAFE'): <matplotlib.text.Text at 0x125d21350>,
#  ('31_BROWN SUGAR KITCHEN',
#   '156_THE SLANTED DOOR'): <matplotlib.text.Text at 0x125d39650>,
#  ('31_BROWN SUGAR KITCHEN',
#   '158_TILDEN REGIONAL PARK'): <matplotlib.text.Text at 0x125d21910>,
#  ('31_BROWN SUGAR KITCHEN',
#   '38_CHEESE BOARD PIZZA'): <matplotlib.text.Text at 0x125d39090>,
#  ('38_CHEESE BOARD PIZZA',
#   '156_THE SLANTED DOOR'): <matplotlib.text.Text at 0x125d457d0>,
#  ('38_CHEESE BOARD PIZZA',
#   '158_TILDEN REGIONAL PARK'): <matplotlib.text.Text at 0x125d52390>}

# %%
points = data_filtered[['lat','long']]

# %%
points.head()
# Out:
#            lat        long
# 26   37.776196 -122.423316
# 31   37.820328 -122.288797
# 38   37.879872 -122.269479
# 142  37.763237 -122.415483
# 156  37.796189 -122.394041

# %%
points.to_csv('points.csv', sep='\t', encoding='utf-8')

# %%
points.head()
# Out:
#            lat        long
# 26   37.776196 -122.423316
# 31   37.820328 -122.288797
# 38   37.879872 -122.269479
# 142  37.763237 -122.415483
# 156  37.796189 -122.394041

# %%
import csv
from math import radians, cos, sin, asin, sqrt
from pulp import *

f = open('points.csv', 'w')
w = csv.writer(f)
w.writerow(["place_A", "Lat_A", "Lon_A", "place_B", "Lat_B","Lon_B"])
for x in cross_places:
    w.writerow([x[0][0],x[0][1],x[0][2],x[1][0],x[1][1],x[1][2]])
f.close()

in_points = []
with open('points.csv') as f:
    reader = csv.reader(f)
    headers = next(f)
    for x in reader:
        in_points.append(x)
f.close()

print in_points

new_data_edges = [(x[0],x[3], {'weight': float(haversine([x[4], x[5]], [x[1],x[2]]))}) for x in in_points]


G_new=nx.Graph()
G_new.add_edges_from(new_data_edges)
pos = nx.spring_layout(G_new)
path = nx.shortest_path(G_new)
plt.figure(figsize=(15,10))
#nx.draw(G_new,pos,node_color='seagreen', with_labels=True, font_size=10)
nx.draw_networkx_nodes(G_new,pos,node_color='m', font_size=7, with_labels=True, font_family='sans-serif')
nx.draw_networkx_edges(G_new,pos,node_color='c', font_size=7, with_labels=True, font_family='sans-serif')
#nx.draw_networkx_edge_labels(G_new,pos,node_color='c', font_size=7, with_labels=True, font_family='sans-serif')
 
# Clique Analysis
find_cliq = nx.find_cliques(G_new)
lst_clqs,unq_places_clq = extract_clusters(find_cliq)
print lst_clqs
# Out:
# [['26_BLUE BOTTLE COFFEE', '37.776196', '-122.42331599999999', '31_BROWN SUGAR KITCHEN', '37.820327899999995', '-122.28879679999999'], ['26_BLUE BOTTLE COFFEE', '37.776196', '-122.42331599999999', '38_CHEESE BOARD PIZZA', '37.87987229999999', '-122.2694794'], ['26_BLUE BOTTLE COFFEE', '37.776196', '-122.42331599999999', '142_STABLE CAFE', '37.76323670000001', '-122.4154832'], ['26_BLUE BOTTLE COFFEE', '37.776196', '-122.42331599999999', '156_THE SLANTED DOOR', '37.796188799999996', '-122.39404099999999'], ['26_BLUE BOTTLE COFFEE', '37.776196', '-122.42331599999999', '158_TILDEN REGIONAL PARK', '37.892767000000006', '-122.242451'], ['31_BROWN SUGAR KITCHEN', '37.820327899999995', '-122.28879679999999', '26_BLUE BOTTLE COFFEE', '37.776196', '-122.42331599999999'], ['31_BROWN SUGAR KITCHEN', '37.820327899999995', '-122.28879679999999', '38_CHEESE BOARD PIZZA', '37.87987229999999', '-122.2694794'], ['31_BROWN SUGAR KITCHEN', '37.820327899999995', '-122.28879679999999', '142_STABLE CAFE', '37.76323670000001', '-122.4154832'], ['31_BROWN SUGAR KITCHEN', '37.820327899999995', '-122.28879679999999', '156_THE SLANTED DOOR', '37.796188799999996', '-122.39404099999999'], ['31_BROWN SUGAR KITCHEN', '37.820327899999995', '-122.28879679999999', '158_TILDEN REGIONAL PARK', '37.892767000000006', '-122.242451'], ['38_CHEESE BOARD PIZZA', '37.87987229999999', '-122.2694794', '26_BLUE BOTTLE COFFEE', '37.776196', '-122.42331599999999'], ['38_CHEESE BOARD PIZZA', '37.87987229999999', '-122.2694794', '31_BROWN SUGAR KITCHEN', '37.820327899999995', '-122.28879679999999'], ['38_CHEESE BOARD PIZZA', '37.87987229999999', '-122.2694794', '142_STABLE CAFE', '37.76323670000001', '-122.4154832'], ['38_CHEESE BOARD PIZZA', '37.87987229999999', '-122.2694794', '156_THE SLANTED DOOR', '37.796188799999996', '-122.39404099999999'], ['38_CHEESE BOARD PIZZA', '37.87987229999999', '-122.2694794', '158_TILDEN REGIONAL PARK', '37.892767000000006', '-122.242451'], ['142_STABLE CAFE', '37.76323670000001', '-122.4154832', '26_BLUE BOTTLE COFFEE', '37.776196', '-122.42331599999999'], ['142_STABLE CAFE', '37.76323670000001', '-122.4154832', '31_BROWN SUGAR KITCHEN', '37.820327899999995', '-122.28879679999999'], ['142_STABLE CAFE', '37.76323670000001', '-122.4154832', '38_CHEESE BOARD PIZZA', '37.87987229999999', '-122.2694794'], ['142_STABLE CAFE', '37.76323670000001', '-122.4154832', '156_THE SLANTED DOOR', '37.796188799999996', '-122.39404099999999'], ['142_STABLE CAFE', '37.76323670000001', '-122.4154832', '158_TILDEN REGIONAL PARK', '37.892767000000006', '-122.242451'], ['156_THE SLANTED DOOR', '37.796188799999996', '-122.39404099999999', '26_BLUE BOTTLE COFFEE', '37.776196', '-122.42331599999999'], ['156_THE SLANTED DOOR', '37.796188799999996', '-122.39404099999999', '31_BROWN SUGAR KITCHEN', '37.820327899999995', '-122.28879679999999'], ['156_THE SLANTED DOOR', '37.796188799999996', '-122.39404099999999', '38_CHEESE BOARD PIZZA', '37.87987229999999', '-122.2694794'], ['156_THE SLANTED DOOR', '37.796188799999996', '-122.39404099999999', '142_STABLE CAFE', '37.76323670000001', '-122.4154832'], ['156_THE SLANTED DOOR', '37.796188799999996', '-122.39404099999999', '158_TILDEN REGIONAL PARK', '37.892767000000006', '-122.242451'], ['158_TILDEN REGIONAL PARK', '37.892767000000006', '-122.242451', '26_BLUE BOTTLE COFFEE', '37.776196', '-122.42331599999999'], ['158_TILDEN REGIONAL PARK', '37.892767000000006', '-122.242451', '31_BROWN SUGAR KITCHEN', '37.820327899999995', '-122.28879679999999'], ['158_TILDEN REGIONAL PARK', '37.892767000000006', '-122.242451', '38_CHEESE BOARD PIZZA', '37.87987229999999', '-122.2694794'], ['158_TILDEN REGIONAL PARK', '37.892767000000006', '-122.242451', '142_STABLE CAFE', '37.76323670000001', '-122.4154832'], ['158_TILDEN REGIONAL PARK', '37.892767000000006', '-122.242451', '156_THE SLANTED DOOR', '37.796188799999996', '-122.39404099999999']]
# [['26_BLUE BOTTLE COFFEE', '38_CHEESE BOARD PIZZA', '158_TILDEN REGIONAL PARK', '31_BROWN SUGAR KITCHEN', '142_STABLE CAFE', '156_THE SLANTED DOOR']]

# %%
points
# Out:
#            lat        long
# 26   37.776196 -122.423316
# 31   37.820328 -122.288797
# 38   37.879872 -122.269479
# 142  37.763237 -122.415483
# 156  37.796189 -122.394041
# 158  37.892767 -122.242451
# 159  38.107038 -122.862864

# %%
nx.clustering(G_new)
# Out:
# {'142_STABLE CAFE': 1.0,
#  '156_THE SLANTED DOOR': 1.0,
#  '158_TILDEN REGIONAL PARK': 1.0,
#  '26_BLUE BOTTLE COFFEE': 1.0,
#  '31_BROWN SUGAR KITCHEN': 1.0,
#  '38_CHEESE BOARD PIZZA': 1.0}

# %%
nx.all_pairs_node_connectivity(G_new)
# Out:
# {'142_STABLE CAFE': {'156_THE SLANTED DOOR': 5,
#   '158_TILDEN REGIONAL PARK': 5,
#   '26_BLUE BOTTLE COFFEE': 5,
#   '31_BROWN SUGAR KITCHEN': 5,
#   '38_CHEESE BOARD PIZZA': 5},
#  '156_THE SLANTED DOOR': {'142_STABLE CAFE': 5,
#   '158_TILDEN REGIONAL PARK': 5,
#   '26_BLUE BOTTLE COFFEE': 5,
#   '31_BROWN SUGAR KITCHEN': 5,
#   '38_CHEESE BOARD PIZZA': 5},
#  '158_TILDEN REGIONAL PARK': {'142_STABLE CAFE': 5,
#   '156_THE SLANTED DOOR': 5,
#   '26_BLUE BOTTLE COFFEE': 5,
#   '31_BROWN SUGAR KITCHEN': 5,
#   '38_CHEESE BOARD PIZZA': 5},
#  '26_BLUE BOTTLE COFFEE': {'142_STABLE CAFE': 5,
#   '156_THE SLANTED DOOR': 5,
#   '158_TILDEN REGIONAL PARK': 5,
#   '31_BROWN SUGAR KITCHEN': 5,
#   '38_CHEESE BOARD PIZZA': 5},
#  '31_BROWN SUGAR KITCHEN': {'142_STABLE CAFE': 5,
#   '156_THE SLANTED DOOR': 5,
#   '158_TILDEN REGIONAL PARK': 5,
#   '26_BLUE BOTTLE COFFEE': 5,
#   '38_CHEESE BOARD PIZZA': 5},
#  '38_CHEESE BOARD PIZZA': {'142_STABLE CAFE': 5,
#   '156_THE SLANTED DOOR': 5,
#   '158_TILDEN REGIONAL PARK': 5,
#   '26_BLUE BOTTLE COFFEE': 5,
#   '31_BROWN SUGAR KITCHEN': 5}}

# %%
# nx.all_pairs_shortest_path(opt_G, cutoff = 2)
nx.shortest_path(G_new)
# Out:
# {'142_STABLE CAFE': {'142_STABLE CAFE': ['142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['142_STABLE CAFE', '156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['142_STABLE CAFE', '158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['142_STABLE CAFE', '26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['142_STABLE CAFE', '31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['142_STABLE CAFE', '38_CHEESE BOARD PIZZA']},
#  '156_THE SLANTED DOOR': {'142_STABLE CAFE': ['156_THE SLANTED DOOR',
#    '142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['156_THE SLANTED DOOR',
#    '158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['156_THE SLANTED DOOR', '26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['156_THE SLANTED DOOR', '31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['156_THE SLANTED DOOR', '38_CHEESE BOARD PIZZA']},
#  '158_TILDEN REGIONAL PARK': {'142_STABLE CAFE': ['158_TILDEN REGIONAL PARK',
#    '142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['158_TILDEN REGIONAL PARK', '156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['158_TILDEN REGIONAL PARK',
#    '26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['158_TILDEN REGIONAL PARK',
#    '31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['158_TILDEN REGIONAL PARK',
#    '38_CHEESE BOARD PIZZA']},
#  '26_BLUE BOTTLE COFFEE': {'142_STABLE CAFE': ['26_BLUE BOTTLE COFFEE',
#    '142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['26_BLUE BOTTLE COFFEE', '156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['26_BLUE BOTTLE COFFEE',
#    '158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['26_BLUE BOTTLE COFFEE',
#    '31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['26_BLUE BOTTLE COFFEE', '38_CHEESE BOARD PIZZA']},
#  '31_BROWN SUGAR KITCHEN': {'142_STABLE CAFE': ['31_BROWN SUGAR KITCHEN',
#    '142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['31_BROWN SUGAR KITCHEN', '156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['31_BROWN SUGAR KITCHEN',
#    '158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['31_BROWN SUGAR KITCHEN', '26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['31_BROWN SUGAR KITCHEN',
#    '38_CHEESE BOARD PIZZA']},
#  '38_CHEESE BOARD PIZZA': {'142_STABLE CAFE': ['38_CHEESE BOARD PIZZA',
#    '142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['38_CHEESE BOARD PIZZA', '156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['38_CHEESE BOARD PIZZA',
#    '158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['38_CHEESE BOARD PIZZA', '26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['38_CHEESE BOARD PIZZA',
#    '31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['38_CHEESE BOARD PIZZA']}}

# %%
nx.all_pairs_shortest_path(G_new, cutoff = 3)
# Out:
# {'142_STABLE CAFE': {'142_STABLE CAFE': ['142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['142_STABLE CAFE', '156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['142_STABLE CAFE', '158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['142_STABLE CAFE', '26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['142_STABLE CAFE', '31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['142_STABLE CAFE', '38_CHEESE BOARD PIZZA']},
#  '156_THE SLANTED DOOR': {'142_STABLE CAFE': ['156_THE SLANTED DOOR',
#    '142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['156_THE SLANTED DOOR',
#    '158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['156_THE SLANTED DOOR', '26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['156_THE SLANTED DOOR', '31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['156_THE SLANTED DOOR', '38_CHEESE BOARD PIZZA']},
#  '158_TILDEN REGIONAL PARK': {'142_STABLE CAFE': ['158_TILDEN REGIONAL PARK',
#    '142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['158_TILDEN REGIONAL PARK', '156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['158_TILDEN REGIONAL PARK',
#    '26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['158_TILDEN REGIONAL PARK',
#    '31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['158_TILDEN REGIONAL PARK',
#    '38_CHEESE BOARD PIZZA']},
#  '26_BLUE BOTTLE COFFEE': {'142_STABLE CAFE': ['26_BLUE BOTTLE COFFEE',
#    '142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['26_BLUE BOTTLE COFFEE', '156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['26_BLUE BOTTLE COFFEE',
#    '158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['26_BLUE BOTTLE COFFEE',
#    '31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['26_BLUE BOTTLE COFFEE', '38_CHEESE BOARD PIZZA']},
#  '31_BROWN SUGAR KITCHEN': {'142_STABLE CAFE': ['31_BROWN SUGAR KITCHEN',
#    '142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['31_BROWN SUGAR KITCHEN', '156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['31_BROWN SUGAR KITCHEN',
#    '158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['31_BROWN SUGAR KITCHEN', '26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['31_BROWN SUGAR KITCHEN',
#    '38_CHEESE BOARD PIZZA']},
#  '38_CHEESE BOARD PIZZA': {'142_STABLE CAFE': ['38_CHEESE BOARD PIZZA',
#    '142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['38_CHEESE BOARD PIZZA', '156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['38_CHEESE BOARD PIZZA',
#    '158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['38_CHEESE BOARD PIZZA', '26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['38_CHEESE BOARD PIZZA',
#    '31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['38_CHEESE BOARD PIZZA']}}

# %%
nx.all_pairs_shortest_path(G_new, cutoff = 4)
# Out:
# {'142_STABLE CAFE': {'142_STABLE CAFE': ['142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['142_STABLE CAFE', '156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['142_STABLE CAFE', '158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['142_STABLE CAFE', '26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['142_STABLE CAFE', '31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['142_STABLE CAFE', '38_CHEESE BOARD PIZZA']},
#  '156_THE SLANTED DOOR': {'142_STABLE CAFE': ['156_THE SLANTED DOOR',
#    '142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['156_THE SLANTED DOOR',
#    '158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['156_THE SLANTED DOOR', '26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['156_THE SLANTED DOOR', '31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['156_THE SLANTED DOOR', '38_CHEESE BOARD PIZZA']},
#  '158_TILDEN REGIONAL PARK': {'142_STABLE CAFE': ['158_TILDEN REGIONAL PARK',
#    '142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['158_TILDEN REGIONAL PARK', '156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['158_TILDEN REGIONAL PARK',
#    '26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['158_TILDEN REGIONAL PARK',
#    '31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['158_TILDEN REGIONAL PARK',
#    '38_CHEESE BOARD PIZZA']},
#  '26_BLUE BOTTLE COFFEE': {'142_STABLE CAFE': ['26_BLUE BOTTLE COFFEE',
#    '142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['26_BLUE BOTTLE COFFEE', '156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['26_BLUE BOTTLE COFFEE',
#    '158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['26_BLUE BOTTLE COFFEE',
#    '31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['26_BLUE BOTTLE COFFEE', '38_CHEESE BOARD PIZZA']},
#  '31_BROWN SUGAR KITCHEN': {'142_STABLE CAFE': ['31_BROWN SUGAR KITCHEN',
#    '142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['31_BROWN SUGAR KITCHEN', '156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['31_BROWN SUGAR KITCHEN',
#    '158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['31_BROWN SUGAR KITCHEN', '26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['31_BROWN SUGAR KITCHEN',
#    '38_CHEESE BOARD PIZZA']},
#  '38_CHEESE BOARD PIZZA': {'142_STABLE CAFE': ['38_CHEESE BOARD PIZZA',
#    '142_STABLE CAFE'],
#   '156_THE SLANTED DOOR': ['38_CHEESE BOARD PIZZA', '156_THE SLANTED DOOR'],
#   '158_TILDEN REGIONAL PARK': ['38_CHEESE BOARD PIZZA',
#    '158_TILDEN REGIONAL PARK'],
#   '26_BLUE BOTTLE COFFEE': ['38_CHEESE BOARD PIZZA', '26_BLUE BOTTLE COFFEE'],
#   '31_BROWN SUGAR KITCHEN': ['38_CHEESE BOARD PIZZA',
#    '31_BROWN SUGAR KITCHEN'],
#   '38_CHEESE BOARD PIZZA': ['38_CHEESE BOARD PIZZA']}}

# %%
nx.closeness_vitality(G, weight='haversine')
# Out:
# {'142_STABLE CAFE': 10.0,
#  '156_THE SLANTED DOOR': 10.0,
#  '158_TILDEN REGIONAL PARK': 10.0,
#  '26_BLUE BOTTLE COFFEE': 10.0,
#  '31_BROWN SUGAR KITCHEN': 10.0,
#  '38_CHEESE BOARD PIZZA': 10.0}

# %%
nx.dijkstra_path(G_new, '26_BLUE BOTTLE COFFEE','38_CHEESE BOARD PIZZA')
# Out:
# ['26_BLUE BOTTLE COFFEE', '156_THE SLANTED DOOR', '38_CHEESE BOARD PIZZA']

# %%
nx.dijkstra_path(G_new, '38_CHEESE BOARD PIZZA','158_TILDEN REGIONAL PARK')
# Out:
# ['38_CHEESE BOARD PIZZA', '158_TILDEN REGIONAL PARK']

# %%
nx.dijkstra_path(G_new,'142_STABLE CAFE','158_TILDEN REGIONAL PARK')
# Out:
# ['142_STABLE CAFE', '158_TILDEN REGIONAL PARK']

# %%
nx.dijkstra_path(G_new,'38_CHEESE BOARD PIZZA','142_STABLE CAFE')
# Out:
# ['38_CHEESE BOARD PIZZA', '142_STABLE CAFE']

# %%
data_filtered
# Out:
#                             name  place_id  \
# 26            BLUE BOTTLE COFFEE        26
# 31           BROWN SUGAR KITCHEN        31
# 38            CHEESE BOARD PIZZA        38
# 142                  STABLE CAFE       142
# 156             THE SLANTED DOOR       156
# 158         TILDEN REGIONAL PARK       158
# 159  TOMALES BAY RESORT & MARINA       159
#
#                                                  types        lat        long  \
# 26   [cafe, food, store, point_of_interest, establi...  37.776196 -122.423316
# 31   [restaurant, food, point_of_interest, establis...  37.820328 -122.288797
# 38   [restaurant, food, point_of_interest, establis...  37.879872 -122.269479
# 142  [cafe, meal_takeaway, restaurant, food, store,...  37.763237 -122.415483
# 156  [bar, restaurant, food, point_of_interest, est...  37.796189 -122.394041
# 158           [park, point_of_interest, establishment]  37.892767 -122.242451
# 159        [lodging, point_of_interest, establishment]  38.107038 -122.862864
#
#     places
# 26     BBC
# 31     BSK
# 38     CBP
# 142     SC
# 156    TSD
# 158    TRP
# 159   TBRM

# %%
# compute distance matrix
from scipy.spatial.distance import pdist, squareform

# not printed as pretty, but the values are correct
distxy = squareform(pdist(data_filtered[['lat', 'long']], metric='euclidean'))
print distxy
# Out:
# [[ 0.          0.14157344  0.18551139  0.01514253  0.0354505   0.21517655
#    0.55014419]
#  [ 0.14157344  0.          0.0625995   0.13895628  0.10797702  0.08599626
#    0.64168181]
#  [ 0.18551139  0.0625995   0.          0.18687154  0.15006172  0.02994675
#    0.63538119]
#  [ 0.01514253  0.13895628  0.18687154  0.          0.03931423  0.21614403
#    0.56422395]
#  [ 0.0354505   0.10797702  0.15006172  0.03931423  0.          0.17974114
#    0.56251398]
#  [ 0.21517655  0.08599626  0.02994675  0.21614403  0.17974114  0.
#    0.65637189]
#  [ 0.55014419  0.64168181  0.63538119  0.56422395  0.56251398  0.65637189
#    0.        ]]

# %%
# # perform clustering and plot the dendrogram
# plt.figure(figsize=(15,10))
# from scipy.cluster.hierarchy import linkage, dendrogram

# R = dendrogram(linkage(distxy, method='complete'), labels=data_filtered.name.values, leaf_rotation=45) #leaf_label_rotation

# %%
from scipy.spatial import KDTree

# %%
from scipy.cluster.hierarchy import linkage, dendrogram
# calculate full dendrogram
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('index')
plt.ylabel('distance')
dendrogram(
    linkage(distxy),
    leaf_rotation=90.,  # rotates the x axis labels
    leaf_font_size=8.,
    labels=data_filtered.name.values,# font size for the x axis labels
)
plt.show()

# %%
plt.figure(figsize=(25, 10))
plt.title('Hierarchical Clustering Dendrogram (truncated)')
plt.xlabel('sample index')
plt.ylabel('distance')
dendrogram(
    linkage(distxy),
    truncate_mode='lastp',  # show only the last p merged clusters
    p=12,  # show only the last p merged clusters
    show_leaf_counts=False,  # otherwise numbers in brackets are counts
    leaf_rotation=90.,
    leaf_font_size=12.,
    labels=data_filtered.name.values,# font size for the x axis labels
    show_contracted=True,  # to get a distribution impression in truncated branches
)
plt.show()

# %%
data_filtered
# Out:
#                             name  place_id  \
# 26            BLUE BOTTLE COFFEE        26
# 31           BROWN SUGAR KITCHEN        31
# 38            CHEESE BOARD PIZZA        38
# 142                  STABLE CAFE       142
# 156             THE SLANTED DOOR       156
# 158         TILDEN REGIONAL PARK       158
# 159  TOMALES BAY RESORT & MARINA       159
#
#                                                  types        lat        long  \
# 26   [cafe, food, store, point_of_interest, establi...  37.776196 -122.423316
# 31   [restaurant, food, point_of_interest, establis...  37.820328 -122.288797
# 38   [restaurant, food, point_of_interest, establis...  37.879872 -122.269479
# 142  [cafe, meal_takeaway, restaurant, food, store,...  37.763237 -122.415483
# 156  [bar, restaurant, food, point_of_interest, est...  37.796189 -122.394041
# 158           [park, point_of_interest, establishment]  37.892767 -122.242451
# 159        [lodging, point_of_interest, establishment]  38.107038 -122.862864
#
#     places
# 26     BBC
# 31     BSK
# 38     CBP
# 142     SC
# 156    TSD
# 158    TRP
# 159   TBRM

# %%
data_filtered.to_csv('data/geocode.csv')

# %%
from scipy.cluster.hierarchy import fcluster
Z = linkage(distxy)
thing = fcluster(Z, 5, criterion='maxclust')
thing
# Out:
# array([1, 4, 3, 1, 2, 3, 5], dtype=int32)

# %%
from scipy.cluster.hierarchy import fcluster
Z = linkage(distxy)
np.unique(thing, return_counts=True)
min_points = 5
k = 1
while True:
    this_thing = fcluster(Z, k + 1, criterion='maxclust')
    thing_counts = np.unique(this_thing, return_counts=True)
    if thing_counts[1][0] < min_points:
        break
    good_thing, good_counts = this_thing, thing_counts
    k += 1
    
print k
print good_thing
print good_counts
# Out:
# 2
# [1 1 1 1 1 1 2]
# (array([1, 2], dtype=int32), array([6, 1]))

# %%
from scipy.cluster.hierarchy import fcluster
Z = linkage(distxy)
np.unique(thing, return_counts=True)
min_points = 6
k = 1
while True:
    this_thing = fcluster(Z, k + 1, criterion='maxclust')
    thing_counts = np.unique(this_thing, return_counts=True)
    if thing_counts[1][0] < min_points:
        break
    good_thing, good_counts = this_thing, thing_counts
    k += 1
    
print k
print good_thing
print good_counts
# Out:
# 2
# [1 1 1 1 1 1 2]
# (array([1, 2], dtype=int32), array([6, 1]))

# %%
from scipy.cluster.hierarchy import fcluster
Z = linkage(distxy)
thing = fcluster(Z, 3, criterion='maxclust')
thing


#raw input: have 8 places, want to do four of them. 

#check the largest group is the same, return that group
#grab those indices
# Out:
# array([1, 2, 2, 1, 1, 2, 3], dtype=int32)

# %%
plt.figure(figsize=(12,7))
last = Z[-10:, 2]
last_rev = last[::-1]
idxs = np.arange(1, len(last) + 1)
plt.plot(idxs, last_rev)

acceleration = np.diff(last, 2)  # 2nd derivative of the distances
acceleration_rev = acceleration[::-1]
plt.plot(idxs[:-2] + 1, acceleration_rev)
plt.show()
k = acceleration_rev.argmax() + 2  # if idx 0 is the max of this we want 2 clusters
print "clusters:", k
# Out:
# clusters: 2

# %%
from scipy.cluster.hierarchy import ClusterNode, leaves_list

leaves = leaves_list(Z)
print leaves
# Out:
# [6 4 0 3 1 2 5]

# %%
from geopy.geocoders import GoogleV3
from geopy.geocoders import Nominatim
import time

geolocator = GoogleV3()
geolocator2 = Nominatim()

# %%
from geopy.distance import vincenty, great_circle
blue_bottle_coffee = (37.776196, -122.423316)
brown_sugar_kitchen = (37.820328, -122.288797)
print(vincenty(blue_bottle_coffee,brown_sugar_kitchen).miles)
print(great_circle(blue_bottle_coffee,brown_sugar_kitchen).miles)
# Out:
# 7.96604477866
# 7.95425139742

# %%
from fastcluster import *
data_link = linkage(distxy) 
# %timeit data_link = linkage(distxy, method='single', metric='euclidean', preserve_input=True)
# Out:
# The slowest run took 9.28 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 3: 19.4 µs per loop

# %%
import graphlab as gl
import pandas as pd
import graphlab as gl

# %%
data = gl.SFrame.read_csv('points.csv')
data['weight'] = .5
data.show
# Out:
# Finished parsing file /Users/samirubenfeld/Desktop/capstone/points.csv
# Parsing completed. Parsed 30 lines in 0.02591 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[str,float,float,str,float,float]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /Users/samirubenfeld/Desktop/capstone/points.csv
# Parsing completed. Parsed 30 lines in 0.017241 secs.
# <bound method SFrame.show of Columns:
# 	place_A	str
# 	Lat_A	float
# 	Lon_A	float
# 	place_B	str
# 	Lat_B	float
# 	Lon_B	float
# 	weight	float
#
# Rows: 30
#
# Data:
# +------------------------+------------+--------------+--------------------------+
# |        place_A         |   Lat_A    |    Lon_A     |         place_B          |
# +------------------------+------------+--------------+--------------------------+
# | 26_BLUE BOTTLE COFFEE  | 37.776196  | -122.423316  |  31_BROWN SUGAR KITCHEN  |
# | 26_BLUE BOTTLE COFFEE  | 37.776196  | -122.423316  |  38_CHEESE BOARD PIZZA   |
# | 26_BLUE BOTTLE COFFEE  | 37.776196  | -122.423316  |     142_STABLE CAFE      |
# | 26_BLUE BOTTLE COFFEE  | 37.776196  | -122.423316  |   156_THE SLANTED DOOR   |
# | 26_BLUE BOTTLE COFFEE  | 37.776196  | -122.423316  | 158_TILDEN REGIONAL PARK |
# | 31_BROWN SUGAR KITCHEN | 37.8203279 | -122.2887968 |  26_BLUE BOTTLE COFFEE   |
# | 31_BROWN SUGAR KITCHEN | 37.8203279 | -122.2887968 |  38_CHEESE BOARD PIZZA   |
# | 31_BROWN SUGAR KITCHEN | 37.8203279 | -122.2887968 |     142_STABLE CAFE      |
# | 31_BROWN SUGAR KITCHEN | 37.8203279 | -122.2887968 |   156_THE SLANTED DOOR   |
# | 31_BROWN SUGAR KITCHEN | 37.8203279 | -122.2887968 | 158_TILDEN REGIONAL PARK |
# +------------------------+------------+--------------+--------------------------+
# +------------+--------------+--------+
# |   Lat_B    |    Lon_B     | weight |
# +------------+--------------+--------+
# | 37.8203279 | -122.2887968 |  0.5   |
# | 37.8798723 | -122.2694794 |  0.5   |
# | 37.7632367 | -122.4154832 |  0.5   |
# | 37.7961888 | -122.394041  |  0.5   |
# | 37.892767  | -122.242451  |  0.5   |
# | 37.776196  | -122.423316  |  0.5   |
# | 37.8798723 | -122.2694794 |  0.5   |
# | 37.7632367 | -122.4154832 |  0.5   |
# | 37.7961888 | -122.394041  |  0.5   |
# | 37.892767  | -122.242451  |  0.5   |
# +------------+--------------+--------+
# [30 rows x 7 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.>

# %%
geo_data = gl.SFrame.read_csv('data/geocode.csv')
geo_data['weight'] = .5
geo_data.show
# Out:
# Finished parsing file /Users/samirubenfeld/Desktop/capstone/data/geocode.csv
# Parsing completed. Parsed 7 lines in 0.015604 secs.
# ------------------------------------------------------
# Inferred types from first 100 line(s) of file as
# column_type_hints=[int,str,int,list,float,float,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# Finished parsing file /Users/samirubenfeld/Desktop/capstone/data/geocode.csv
# Parsing completed. Parsed 7 lines in 0.020541 secs.
# <bound method SFrame.show of Columns:
# 	X1	int
# 	name	str
# 	place_id	int
# 	types	list
# 	lat	float
# 	long	float
# 	places	str
# 	weight	float
#
# Rows: 7
#
# Data:
# +-----+-----------------------------+----------+-------------------------------+
# |  X1 |             name            | place_id |             types             |
# +-----+-----------------------------+----------+-------------------------------+
# |  26 |      BLUE BOTTLE COFFEE     |    26    | [cafe, food, store, point_... |
# |  31 |     BROWN SUGAR KITCHEN     |    31    | [restaurant, food, point_o... |
# |  38 |      CHEESE BOARD PIZZA     |    38    | [restaurant, food, point_o... |
# | 142 |         STABLE CAFE         |   142    | [cafe, meal_takeaway, rest... |
# | 156 |       THE SLANTED DOOR      |   156    | [bar, restaurant, food, po... |
# | 158 |     TILDEN REGIONAL PARK    |   158    | [park, point_of_interest, ... |
# | 159 | TOMALES BAY RESORT & MARINA |   159    | [lodging, point_of_interes... |
# +-----+-----------------------------+----------+-------------------------------+
# +------------+--------------+--------+--------+
# |    lat     |     long     | places | weight |
# +------------+--------------+--------+--------+
# | 37.776196  | -122.423316  |  BBC   |  0.5   |
# | 37.8203279 | -122.2887968 |  BSK   |  0.5   |
# | 37.8798723 | -122.2694794 |  CBP   |  0.5   |
# | 37.7632367 | -122.4154832 |   SC   |  0.5   |
# | 37.7961888 | -122.394041  |  TSD   |  0.5   |
# | 37.892767  | -122.242451  |  TRP   |  0.5   |
# | 38.1070379 | -122.8628638 |  TBRM  |  0.5   |
# +------------+--------------+--------+--------+
# [7 rows x 8 columns]
# >

# %%
geo_data
# Out:
# Columns:
# 	X1	int
# 	name	str
# 	place_id	int
# 	types	list
# 	lat	float
# 	long	float
# 	places	str
# 	weight	float
#
# Rows: 7
#
# Data:
# +-----+-----------------------------+----------+-------------------------------+
# |  X1 |             name            | place_id |             types             |
# +-----+-----------------------------+----------+-------------------------------+
# |  26 |      BLUE BOTTLE COFFEE     |    26    | [cafe, food, store, point_... |
# |  31 |     BROWN SUGAR KITCHEN     |    31    | [restaurant, food, point_o... |
# |  38 |      CHEESE BOARD PIZZA     |    38    | [restaurant, food, point_o... |
# | 142 |         STABLE CAFE         |   142    | [cafe, meal_takeaway, rest... |
# | 156 |       THE SLANTED DOOR      |   156    | [bar, restaurant, food, po... |
# | 158 |     TILDEN REGIONAL PARK    |   158    | [park, point_of_interest, ... |
# | 159 | TOMALES BAY RESORT & MARINA |   159    | [lodging, point_of_interes... |
# +-----+-----------------------------+----------+-------------------------------+
# +------------+--------------+--------+--------+
# |    lat     |     long     | places | weight |
# +------------+--------------+--------+--------+
# | 37.776196  | -122.423316  |  BBC   |  0.5   |
# | 37.8203279 | -122.2887968 |  BSK   |  0.5   |
# | 37.8798723 | -122.2694794 |  CBP   |  0.5   |
# | 37.7632367 | -122.4154832 |   SC   |  0.5   |
# | 37.7961888 | -122.394041  |  TSD   |  0.5   |
# | 37.892767  | -122.242451  |  TRP   |  0.5   |
# | 38.1070379 | -122.8628638 |  TBRM  |  0.5   |
# +------------+--------------+--------+--------+
# [7 rows x 8 columns]

# %%
geo_code_2 = geo_data.select_columns(['name', 'lat', 'long'])

# %%
from graphlab import SGraph, Vertex, Edge
g = SGraph()

# %%
gl.distances.euclidean([37.776196, -122.423316], [37.8203279,-122.2887968])
# Out:
# 0.14157344301192312

# %%
gl.distances.euclidean([37.8798723, -122.2694794], [38.1070379, -122.8628638])
# Out:
# 0.6353811895128196

# %%
df = geo_code_2.select_columns(['lat', 'long'])
df.show
# Out:
# <bound method SFrame.show of Columns:
# 	lat	float
# 	long	float
#
# Rows: 7
#
# Data:
# +------------+--------------+
# |    lat     |     long     |
# +------------+--------------+
# | 37.776196  | -122.423316  |
# | 37.8203279 | -122.2887968 |
# | 37.8798723 | -122.2694794 |
# | 37.7632367 | -122.4154832 |
# | 37.7961888 | -122.394041  |
# | 37.892767  | -122.242451  |
# | 38.1070379 | -122.8628638 |
# +------------+--------------+
# [7 rows x 2 columns]
# >

# %%
gl.distances.euclidean(df[0], df[1])
# Out:
# 0.1415734430152351

# %%
gl.distances.euclidean(df[0], df[2])
# Out:
# 0.18551138692209745

# %%
gl.distances.euclidean(df[0], df[3])
# Out:
# 0.01514252980844302

# %%
gl.distances.euclidean(df[0], df[4])
# Out:
# 0.03545049613415984

# %%
gl.distances.euclidean(df[0], df[5])
# Out:
# 0.21517654674518863

# %%
gl.distances.euclidean(df[0], df[6])
# Out:
# 0.5501441913509169

# %%
# [37.776196, -122.423316]
# [37.8203279, -122.2887968]
# [37.8798723, -122.2694794]
# [37.7632367, -122.4154832]
# [37.7961888, -122.394041]
# [37.892767, -122.242451]
# [38.1070379, -122.8628638]

# %%
def girvan_newman_step(G):
    '''
    INPUT: Graph G
    OUTPUT: None

    Run one step of the Girvan-Newman community detection algorithm.
    Afterwards, the graph will have one more connected component.
    '''
    init_ncomp = nx.number_connected_components(G)
    ncomp = init_ncomp
    while ncomp == init_ncomp:
        bw = Counter(nx.edge_betweenness_centrality(G))
        a, b = bw.most_common(1)[0][0]
        G.remove_edge(a, b)
        ncomp = nx.number_connected_components(G)

# %%
girvan_newman_step(G_new)

# %%
def find_communities_n(G, n):
    '''
    INPUT: Graph G, int n
    OUTPUT: list of lists

    Run the Girvan-Newman algorithm on G for n steps. Return the resulting
    communities.
    '''
    G1 = G.copy()
    for i in xrange(n):
        girvan_newman_step(G1)
    return list(nx.connected_components(G1))

# %%
find_communities_n(G_new, 1)
# Out:
# [{'156_THE SLANTED DOOR',
#   '158_TILDEN REGIONAL PARK',
#   '26_BLUE BOTTLE COFFEE',
#   '38_CHEESE BOARD PIZZA'},
#  {'31_BROWN SUGAR KITCHEN'},
#  {'142_STABLE CAFE'}]

# %%
find_communities_n(G, 2)
# Out:
# [{'156_THE SLANTED DOOR',
#   '158_TILDEN REGIONAL PARK',
#   '26_BLUE BOTTLE COFFEE',
#   '38_CHEESE BOARD PIZZA'},
#  {'31_BROWN SUGAR KITCHEN'},
#  {'142_STABLE CAFE'}]

# %%
find_communities_n(G, 5)
# Out:
# [{'26_BLUE BOTTLE COFFEE'},
#  {'31_BROWN SUGAR KITCHEN'},
#  {'142_STABLE CAFE'},
#  {'38_CHEESE BOARD PIZZA'},
#  {'156_THE SLANTED DOOR'},
#  {'158_TILDEN REGIONAL PARK'}]

# %%
def get_modularity(subgraphs, degrees, num_edges):
    '''
    INPUT:
        subgraphs: graph broken in subgraphs
        degrees: dictionary of degree values of original graph
        num_edges: float, number of edges in original graph
    OUTPUT: Float (modularity value, between -0.5 and 1)

    Return the value of the modularity for the graph G.
    '''
    mod = 0
    for g in subgraphs:
        for node1 in g:
            for node2 in g:
                mod += int(g.has_edge(node1, node2))
                mod -= degrees[node1] * degrees[node2] / (2. * num_edges)
    return mod / (2. * num_edges)

# %%
def find_communities_modularity(G, max_iter=None):
    '''
    INPUT:
        G: networkx Graph
        max_iter: (optional) if given, maximum number of iterations
    OUTPUT: list of lists of strings (node names)

    Run the Girvan-Newman algorithm on G and find the communities with the
    maximum modularity.
    '''
    degrees = G.degree()
    num_edges = G.number_of_edges()
    G1 = G.copy()
    best_modularity = -1.0
    best_comps = nx.connected_components(G1)
    i = 0
    while G1.number_of_edges() > 0:
        subgraphs = nx.connected_component_subgraphs(G1)
        modularity = get_modularity(subgraphs, degrees, num_edges)
        if modularity > best_modularity:
            best_modularity = modularity
            best_comps = list(nx.connected_components(G1))
        girvan_newman_step(G1)
        i += 1
        if max_iter and i >= max_iter:
            break
    return best_comps

# %%
find_communities_modularity(G_new, max_iter=None)
# Out:
# [{'156_THE SLANTED DOOR',
#   '158_TILDEN REGIONAL PARK',
#   '26_BLUE BOTTLE COFFEE',
#   '31_BROWN SUGAR KITCHEN',
#   '38_CHEESE BOARD PIZZA'},
#  {'142_STABLE CAFE'}]

# %%
find_communities_modularity(G, max_iter=None)
# Out:
# [{'142_STABLE CAFE',
#   '156_THE SLANTED DOOR',
#   '158_TILDEN REGIONAL PARK',
#   '26_BLUE BOTTLE COFFEE',
#   '31_BROWN SUGAR KITCHEN',
#   '38_CHEESE BOARD PIZZA'}]

# %%
c = find_communities_modularity(G)
print c
print "Optimal number of communities: %d" % len(c)
# Out:
# [set(['26_BLUE BOTTLE COFFEE', '31_BROWN SUGAR KITCHEN', '142_STABLE CAFE', '38_CHEESE BOARD PIZZA', '156_THE SLANTED DOOR', '158_TILDEN REGIONAL PARK'])]
# Optimal number of communities: 1

# %%
c = find_communities_modularity(G_new)
print c
print "Optimal number of communities: %d" % len(c)
# Out:
# [set(['38_CHEESE BOARD PIZZA', '158_TILDEN REGIONAL PARK', '26_BLUE BOTTLE COFFEE', '156_THE SLANTED DOOR', '31_BROWN SUGAR KITCHEN']), set(['142_STABLE CAFE'])]
# Optimal number of communities: 2
